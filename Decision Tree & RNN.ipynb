# %%
import pandas as pd
import json
import os
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from collections import defaultdict
# Out:
# /Users/yu-jhen/opt/anaconda3/envs/data_analysis/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# # generate state action pair from its children who has the highest value
# def load_data(filename, sep='\t', visit_threshold=5, col='Game_Features'):
#     df = pd.read_csv(filename, sep=sep)
#     features = json.loads(df.iloc[0][col]).keys()
#     data = {"Action": []}

#     for feature in features:
#         data[feature] = []

#     for _, row in df.iterrows():
#         children = df[df['Parent_Name'] == row['Name']]
#         children = children[children['Visits'] >= visit_threshold]
#         if children.shape[0]:
#             child = children.nlargest(1, 'Value')
#             child_features = json.loads(child.iloc[0][col])
#             child_action = child.iloc[0]['Action_Name']
#             for feature in child_features:
#                 data[feature].append(child_features[feature])
#             data['Action'].append(child_action)
            
#     return pd.DataFrame(data)

# %%
# generate state action pair from its children who has the highest value
def load_data(filename, sep='\t', visit_threshold=5, col='Game_Features'):
    df = pd.read_csv(filename, sep=sep)
    features = json.loads(df.iloc[0][col]).keys()
    data = {"Action": []}

    for feature in features:
        data[feature] = []

    for _, row in df.iterrows():
        state_features = json.loads(row[col])
        children = df[df['Parent_Name'] == row['Name']]
        children = children[children['Visits'] >= visit_threshold]
        if children.shape[0]:
            child = children.nlargest(1, 'Value')
            child_action = child.iloc[0]['Action_Name']
            for feature in state_features:
                data[feature].append(state_features[feature])
            data['Action'].append(child_action)
            
    return pd.DataFrame(data)

# %%
dfs = []

for i in os.listdir("DotsAndBoxes"):
    if i.split(".")[-1] != 'csv':
        continue
    print(i)
    dfs.append(load_data(f"DotsAndBoxes/{i}", visit_threshold=1, col='Game_State'))

df = pd.concat(dfs)
df
# Out:
# record_43.csv
# record_57.csv
# record_309.csv
# record_321.csv
# record_447.csv
# record_453.csv
# record_335.csv
# record_80.csv
# record_94.csv
# record_484.csv
# record_490.csv
# record_679.csv
# record_645.csv
# record_123.csv
# record_137.csv
# record_889.csv
# record_651.csv
# record_1077.csv
# record_862.csv
# record_1063.csv
# record_876.csv
# record_686.csv
# record_692.csv
# record_719.csv
# record_731.csv
# record_725.csv
# record_916.csv
# record_902.csv
# record_269.csv
# record_255.csv
# record_533.csv
# record_527.csv
# record_241.csv
# record_296.csv
# record_282.csv
# record_283.csv
# record_297.csv
# record_526.csv
# record_240.csv
# record_254.csv
# record_532.csv
# record_268.csv
# record_903.csv
# record_917.csv
# record_724.csv
# record_730.csv
# record_718.csv
# record_693.csv
# record_687.csv
# record_877.csv
# record_1062.csv
# record_863.csv
# record_1076.csv
# record_136.csv
# record_650.csv
# record_888.csv
# record_644.csv
# record_122.csv
# record_678.csv
# record_491.csv
# record_485.csv
# record_95.csv
# record_81.csv
# record_452.csv
# record_334.csv
# record_320.csv
# record_446.csv
# record_56.csv
# record_308.csv
# record_42.csv
# record_54.csv
# record_478.csv
# record_40.csv
# record_336.csv
# record_450.csv
# record_68.csv
# record_444.csv
# record_322.csv
# record_97.csv
# record_83.csv
# record_493.csv
# record_487.csv
# record_108.csv
# record_652.csv
# record_134.csv
# record_120.csv
# record_646.csv
# record_1060.csv
# record_875.csv
# record_1074.csv
# record_861.csv
# record_691.csv
# record_849.csv
# record_685.csv
# record_1048.csv
# record_726.csv
# record_732.csv
# record_901.csv
# record_915.csv
# record_929.csv
# record_518.csv
# record_242.csv
# record_524.csv
# record_530.csv
# record_256.csv
# record_281.csv
# record_295.csv
# record_294.csv
# record_280.csv
# record_531.csv
# record_257.csv
# record_243.csv
# record_525.csv
# record_519.csv
# record_928.csv
# record_914.csv
# record_900.csv
# record_733.csv
# record_727.csv
# record_1049.csv
# record_684.csv
# record_848.csv
# record_690.csv
# record_860.csv
# record_1075.csv
# record_874.csv
# record_1061.csv
# record_121.csv
# record_647.csv
# record_653.csv
# record_135.csv
# record_109.csv
# record_486.csv
# record_492.csv
# record_82.csv
# record_96.csv
# record_445.csv
# record_323.csv
# record_337.csv
# record_69.csv
# record_451.csv
# record_41.csv
# record_479.csv
# record_55.csv
# record_455.csv
# record_333.csv
# record_327.csv
# record_79.csv
# record_441.csv
# record_51.csv
# record_469.csv
# record_45.csv
# record_496.csv
# record_482.csv
# record_92.csv
# record_86.csv
# record_8.csv
# record_131.csv
# record_657.csv
# record_643.csv
# record_125.csv
# record_119.csv
# record_694.csv
# record_1059.csv
# record_680.csv
# record_858.csv
# record_1065.csv
# record_870.csv
# record_1071.csv
# record_864.csv
# record_723.csv
# record_737.csv
# record_938.csv
# record_904.csv
# record_910.csv
# record_521.csv
# record_247.csv
# record_253.csv
# record_535.csv
# record_509.csv
# record_284.csv
# record_290.csv
# record_291.csv
# record_285.csv
# record_508.csv
# record_252.csv
# record_534.csv
# record_520.csv
# record_246.csv
# record_911.csv
# record_905.csv
# record_939.csv
# record_736.csv
# record_722.csv
# record_865.csv
# record_1070.csv
# record_871.csv
# record_1064.csv
# record_859.csv
# record_681.csv
# record_1058.csv
# record_695.csv
# record_118.csv
# record_642.csv
# record_124.csv
# record_130.csv
# record_656.csv
# record_9.csv
# record_87.csv
# record_93.csv
# record_483.csv
# record_497.csv
# record_44.csv
# record_468.csv
# record_50.csv
# record_326.csv
# record_440.csv
# record_78.csv
# record_454.csv
# record_332.csv
# record_442.csv
# record_324.csv
# record_330.csv
# record_456.csv
# record_46.csv
# record_318.csv
# record_52.csv
# record_481.csv
# record_495.csv
# record_85.csv
# record_91.csv
# record_126.csv
# record_898.csv
# record_640.csv
# record_654.csv
# record_132.csv
# record_668.csv
# record_683.csv
# record_697.csv
# record_1072.csv
# record_867.csv
# record_1066.csv
# record_873.csv
# record_734.csv
# record_720.csv
# record_708.csv
# record_913.csv
# record_907.csv
# record_536.csv
# record_250.csv
# record_244.csv
# record_522.csv
# record_278.csv
# record_293.csv
# record_287.csv
# record_286.csv
# record_292.csv
# record_279.csv
# record_245.csv
# record_523.csv
# record_537.csv
# record_251.csv
# record_906.csv
# record_912.csv
# record_709.csv
# record_721.csv
# record_735.csv
# record_872.csv
# record_1067.csv
# record_866.csv
# record_1073.csv
# record_696.csv
# record_682.csv
# record_669.csv
# record_655.csv
# record_133.csv
# record_127.csv
# record_641.csv
# record_899.csv
# record_90.csv
# record_84.csv
# record_494.csv
# record_480.csv
# record_53.csv
# record_47.csv
# record_319.csv
# record_331.csv
# record_457.csv
# record_443.csv
# record_325.csv
# record_20.csv
# record_418.csv
# record_34.csv
# record_424.csv
# record_342.csv
# record_356.csv
# record_430.csv
# record_381.csv
# record_395.csv
# record_168.csv
# record_140.csv
# record_626.csv
# record_632.csv
# record_154.csv
# record_1014.csv
# record_801.csv
# record_1000.csv
# record_815.csv
# record_183.csv
# record_1028.csv
# record_829.csv
# record_197.csv
# record_752.csv
# record_746.csv
# record_975.csv
# record_961.csv
# record_949.csv
# record_791.csv
# record_785.csv
# record_578.csv
# record_550.csv
# record_236.csv
# record_222.csv
# record_544.csv
# record_593.csv
# record_587.csv
# record_586.csv
# record_592.csv
# record_223.csv
# record_545.csv
# record_551.csv
# record_237.csv
# record_579.csv
# record_784.csv
# record_790.csv
# record_948.csv
# record_960.csv
# record_974.csv
# record_747.csv
# record_753.csv
# record_828.csv
# record_196.csv
# record_182.csv
# record_1029.csv
# record_814.csv
# record_1001.csv
# record_800.csv
# record_1015.csv
# record_633.csv
# record_155.csv
# record_141.csv
# record_627.csv
# record_169.csv
# record_394.csv
# record_380.csv
# record_357.csv
# record_431.csv
# record_425.csv
# record_343.csv
# record_35.csv
# record_419.csv
# record_21.csv
# record_37.csv
# record_369.csv
# record_23.csv
# record_433.csv
# record_355.csv
# record_341.csv
# record_427.csv
# record_396.csv
# record_382.csv
# record_619.csv
# record_157.csv
# record_631.csv
# record_625.csv
# record_143.csv
# record_1003.csv
# record_816.csv
# record_1017.csv
# record_802.csv
# record_194.csv
# record_180.csv
# record_779.csv
# record_745.csv
# record_751.csv
# record_989.csv
# record_962.csv
# record_976.csv
# record_786.csv
# record_792.csv
# record_209.csv
# record_547.csv
# record_221.csv
# record_235.csv
# record_553.csv
# record_584.csv
# record_590.csv
# record_591.csv
# record_585.csv
# record_234.csv
# record_552.csv
# record_546.csv
# record_220.csv
# record_208.csv
# record_793.csv
# record_787.csv
# record_977.csv
# record_963.csv
# record_988.csv
# record_750.csv
# record_744.csv
# record_778.csv
# record_181.csv
# record_195.csv
# record_803.csv
# record_1016.csv
# record_817.csv
# record_1002.csv
# record_624.csv
# record_142.csv
# record_156.csv
# record_630.csv
# record_618.csv
# record_383.csv
# record_397.csv
# record_340.csv
# record_426.csv
# record_432.csv
# record_354.csv
# record_22.csv
# record_36.csv
# record_368.csv
# record_350.csv
# record_436.csv
# record_422.csv
# record_344.csv
# record_32.csv
# record_26.csv
# record_378.csv
# record_393.csv
# record_387.csv
# record_634.csv
# record_152.csv
# record_146.csv
# record_620.csv
# record_608.csv
# record_191.csv
# record_185.csv
# record_1006.csv
# record_813.csv
# record_1012.csv
# record_807.csv
# record_740.csv
# record_998.csv
# record_754.csv
# record_768.csv
# record_783.csv
# record_797.csv
# record_967.csv
# record_973.csv
# record_224.csv
# record_542.csv
# record_556.csv
# record_230.csv
# record_218.csv
# record_581.csv
# record_595.csv
# record_594.csv
# record_580.csv
# record_219.csv
# record_557.csv
# record_231.csv
# record_225.csv
# record_543.csv
# record_972.csv
# record_966.csv
# record_796.csv
# record_782.csv
# record_769.csv
# record_755.csv
# record_999.csv
# record_741.csv
# record_806.csv
# record_1013.csv
# record_812.csv
# record_1007.csv
# record_184.csv
# record_190.csv
# record_609.csv
# record_147.csv
# record_621.csv
# record_635.csv
# record_153.csv
# record_386.csv
# record_392.csv
# record_27.csv
# record_379.csv
# record_33.csv
# record_423.csv
# record_345.csv
# record_351.csv
# record_437.csv
# record_347.csv
# record_421.csv
# record_19.csv
# record_435.csv
# record_353.csv
# record_25.csv
# record_409.csv
# record_31.csv
# record_384.csv
# record_390.csv
# record_623.csv
# record_145.csv
# record_151.csv
# record_637.csv
# record_179.csv
# record_838.csv
# record_186.csv
# record_192.csv
# record_1039.csv
# record_1011.csv
# record_804.csv
# record_1005.csv
# record_810.csv
# record_757.csv
# record_743.csv
# record_794.csv
# record_958.csv
# record_780.csv
# record_970.csv
# record_964.csv
# record_233.csv
# record_555.csv
# record_541.csv
# record_227.csv
# record_569.csv
# record_596.csv
# record_582.csv
# record_583.csv
# record_597.csv
# record_568.csv
# record_540.csv
# record_226.csv
# record_232.csv
# record_554.csv
# record_965.csv
# record_971.csv
# record_781.csv
# record_959.csv
# record_795.csv
# record_742.csv
# record_756.csv
# record_811.csv
# record_1004.csv
# record_805.csv
# record_1010.csv
# record_193.csv
# record_1038.csv
# record_839.csv
# record_187.csv
# record_178.csv
# record_150.csv
# record_636.csv
# record_622.csv
# record_144.csv
# record_391.csv
# record_385.csv
# record_30.csv
# record_408.csv
# record_24.csv
# record_434.csv
# record_352.csv
# record_346.csv
# record_18.csv
# record_420.csv
# record_439.csv
# record_15.csv
# record_405.csv
# record_363.csv
# record_377.csv
# record_411.csv
# record_29.csv
# record_388.csv
# record_149.csv
# record_161.csv
# record_607.csv
# record_613.csv
# record_175.csv
# record_1035.csv
# record_820.csv
# record_1021.csv
# record_834.csv
# record_1009.csv
# record_808.csv
# record_997.csv
# record_983.csv
# record_773.csv
# record_767.csv
# record_954.csv
# record_940.csv
# record_798.csv
# record_968.csv
# record_559.csv
# record_571.csv
# record_217.csv
# record_203.csv
# record_565.csv
# record_202.csv
# record_564.csv
# record_570.csv
# record_216.csv
# record_558.csv
# record_969.csv
# record_799.csv
# record_941.csv
# record_955.csv
# record_766.csv
# record_772.csv
# record_982.csv
# record_996.csv
# record_809.csv
# record_1008.csv
# record_835.csv
# record_1020.csv
# record_821.csv
# record_1034.csv
# record_612.csv
# record_174.csv
# record_160.csv
# record_606.csv
# record_148.csv
# record_389.csv
# record_376.csv
# record_28.csv
# record_410.csv
# record_404.csv
# record_362.csv
# record_14.csv
# record_438.csv
# record_16.csv
# record_348.csv
# record_412.csv
# record_374.csv
# record_360.csv
# record_406.csv
# record_638.csv
# record_176.csv
# record_610.csv
# record_604.csv
# record_162.csv
# record_189.csv
# record_1022.csv
# record_837.csv
# record_1036.csv
# record_823.csv
# record_758.csv
# record_980.csv
# record_994.csv
# record_764.csv
# record_770.csv
# record_943.csv
# record_957.csv
# record_228.csv
# record_566.csv
# record_200.csv
# record_214.csv
# record_572.csv
# record_599.csv
# record_598.csv
# record_215.csv
# record_573.csv
# record_567.csv
# record_201.csv
# record_229.csv
# record_956.csv
# record_942.csv
# record_771.csv
# record_765.csv
# record_995.csv
# record_981.csv
# record_759.csv
# record_822.csv
# record_1037.csv
# record_188.csv
# record_836.csv
# record_1023.csv
# record_605.csv
# record_163.csv
# record_177.csv
# record_611.csv
# record_639.csv
# record_361.csv
# record_407.csv
# record_413.csv
# record_375.csv
# record_17.csv
# record_349.csv
# record_371.csv
# record_417.csv
# record_403.csv
# record_365.csv
# record_13.csv
# record_359.csv
# record_615.csv
# record_173.csv
# record_167.csv
# record_601.csv
# record_629.csv
# record_1027.csv
# record_832.csv
# record_198.csv
# record_1033.csv
# record_826.csv
# record_761.csv
# record_775.csv
# record_985.csv
# record_749.csv
# record_991.csv
# record_946.csv
# record_952.csv
# record_205.csv
# record_563.csv
# record_577.csv
# record_211.csv
# record_239.csv
# record_588.csv
# record_589.csv
# record_238.csv
# record_576.csv
# record_210.csv
# record_204.csv
# record_562.csv
# record_953.csv
# record_947.csv
# record_990.csv
# record_748.csv
# record_984.csv
# record_774.csv
# record_760.csv
# record_199.csv
# record_827.csv
# record_1032.csv
# record_833.csv
# record_1026.csv
# record_628.csv
# record_166.csv
# record_600.csv
# record_614.csv
# record_172.csv
# record_358.csv
# record_12.csv
# record_402.csv
# record_364.csv
# record_370.csv
# record_416.csv
# record_366.csv
# record_38.csv
# record_400.csv
# record_414.csv
# record_372.csv
# record_10.csv
# record_428.csv
# record_399.csv
# record_602.csv
# record_164.csv
# record_170.csv
# record_616.csv
# record_158.csv
# record_819.csv
# record_1018.csv
# record_1030.csv
# record_825.csv
# record_1024.csv
# record_831.csv
# record_776.csv
# record_762.csv
# record_992.csv
# record_986.csv
# record_979.csv
# record_951.csv
# record_789.csv
# record_945.csv
# record_212.csv
# record_574.csv
# record_560.csv
# record_206.csv
# record_548.csv
# record_549.csv
# record_561.csv
# record_207.csv
# record_213.csv
# record_575.csv
# record_944.csv
# record_788.csv
# record_950.csv
# record_978.csv
# record_987.csv
# record_993.csv
# record_763.csv
# record_777.csv
# record_830.csv
# record_1025.csv
# record_824.csv
# record_1031.csv
# record_1019.csv
# record_818.csv
# record_159.csv
# record_171.csv
# record_617.csv
# record_603.csv
# record_165.csv
# record_398.csv
# record_429.csv
# record_11.csv
# record_415.csv
# record_373.csv
# record_367.csv
# record_401.csv
# record_39.csv
# record_62.csv
# record_76.csv
# record_328.csv
# record_300.csv
# record_466.csv
# record_472.csv
# record_314.csv
# record_499.csv
# record_7.csv
# record_89.csv
# record_880.csv
# record_658.csv
# record_894.csv
# record_664.csv
# record_102.csv
# record_116.csv
# record_670.csv
# record_1056.csv
# record_843.csv
# record_1042.csv
# record_857.csv
# record_738.csv
# record_710.csv
# record_704.csv
# record_937.csv
# record_923.csv
# record_248.csv
# record_274.csv
# record_512.csv
# record_506.csv
# record_260.csv
# record_507.csv
# record_261.csv
# record_275.csv
# record_513.csv
# record_249.csv
# record_922.csv
# record_936.csv
# record_705.csv
# record_711.csv
# record_739.csv
# record_856.csv
# record_1043.csv
# record_842.csv
# record_1057.csv
# record_117.csv
# record_671.csv
# record_665.csv
# record_103.csv
# record_895.csv
# record_659.csv
# record_881.csv
# record_88.csv
# record_6.csv
# record_498.csv
# record_473.csv
# record_315.csv
# record_301.csv
# record_467.csv
# record_77.csv
# record_329.csv
# record_63.csv
# record_75.csv
# record_61.csv
# record_459.csv
# record_317.csv
# record_49.csv
# record_471.csv
# record_465.csv
# record_303.csv
# record_4.csv
# record_897.csv
# record_129.csv
# record_883.csv
# record_673.csv
# record_115.csv
# record_101.csv
# record_667.csv
# record_1041.csv
# record_854.csv
# record_1055.csv
# record_698.csv
# record_840.csv
# record_868.csv
# record_1069.csv
# record_707.csv
# record_713.csv
# record_920.csv
# record_934.csv
# record_908.csv
# record_539.csv
# record_263.csv
# record_505.csv
# record_511.csv
# record_277.csv
# record_288.csv
# record_289.csv
# record_510.csv
# record_276.csv
# record_262.csv
# record_504.csv
# record_538.csv
# record_909.csv
# record_935.csv
# record_921.csv
# record_712.csv
# record_706.csv
# record_1068.csv
# record_869.csv
# record_841.csv
# record_699.csv
# record_1054.csv
# record_855.csv
# record_1040.csv
# record_100.csv
# record_666.csv
# record_672.csv
# record_114.csv
# record_882.csv
# record_896.csv
# record_128.csv
# record_5.csv
# record_464.csv
# record_302.csv
# record_316.csv
# record_470.csv
# record_48.csv
# record_458.csv
# record_60.csv
# record_74.csv
# record_474.csv
# record_312.csv
# record_306.csv
# record_460.csv
# record_58.csv
# record_448.csv
# record_70.csv
# record_64.csv
# record_1.csv
# record_110.csv
# record_676.csv
# record_662.csv
# record_104.csv
# record_892.csv
# record_886.csv
# record_138.csv
# record_879.csv
# record_1044.csv
# record_689.csv
# record_851.csv
# record_1050.csv
# record_845.csv
# record_702.csv
# record_716.csv
# record_919.csv
# record_925.csv
# record_931.csv
# record_500.csv
# record_266.csv
# record_272.csv
# record_514.csv
# record_528.csv
# record_299.csv
# record_298.csv
# record_529.csv
# record_273.csv
# record_515.csv
# record_501.csv
# record_267.csv
# record_930.csv
# record_924.csv
# record_918.csv
# record_717.csv
# record_703.csv
# record_844.csv
# record_1051.csv
# record_850.csv
# record_688.csv
# record_1045.csv
# record_878.csv
# record_887.csv
# record_139.csv
# record_893.csv
# record_663.csv
# record_105.csv
# record_111.csv
# record_677.csv
# record_65.csv
# record_71.csv
# record_449.csv
# record_307.csv
# record_59.csv
# record_461.csv
# record_475.csv
# record_313.csv
# record_463.csv
# record_305.csv
# record_311.csv
# record_477.csv
# record_67.csv
# record_339.csv
# record_73.csv
# record_98.csv
# record_2.csv
# record_488.csv
# record_107.csv
# record_661.csv
# record_675.csv
# record_113.csv
# record_885.csv
# record_891.csv
# record_649.csv
# record_1053.csv
# record_846.csv
# record_1047.csv
# record_852.csv
# record_715.csv
# record_701.csv
# record_729.csv
# record_932.csv
# record_926.csv
# record_517.csv
# record_271.csv
# record_265.csv
# record_503.csv
# record_259.csv
# record_258.csv
# record_264.csv
# record_502.csv
# record_516.csv
# record_270.csv
# record_927.csv
# record_933.csv
# record_728.csv
# record_700.csv
# record_714.csv
# record_853.csv
# record_1046.csv
# record_847.csv
# record_1052.csv
# record_648.csv
# record_890.csv
# record_884.csv
# record_674.csv
# record_112.csv
# record_106.csv
# record_660.csv
# record_489.csv
# record_3.csv
# record_99.csv
# record_72.csv
# record_66.csv
# record_338.csv
# record_310.csv
# record_476.csv
# record_462.csv
# record_304.csv
#              Action  Edge_Owner_6061  Edge_Owner_6263  Edge_Owner_6465  \
# 0    (5,0) -> (6,0)                0               -1               -1
# 1    (5,5) -> (6,5)                0               -1               -1
# 2    (5,0) -> (6,0)                0               -1               -1
# 3    (5,0) -> (6,0)                0               -1               -1
# 4    (5,0) -> (6,0)                0               -1               -1
# ..              ...              ...              ...              ...
# 252  (2,0) -> (3,0)                0                1                1
# 253  (2,0) -> (2,1)                0                1                1
# 254  (3,3) -> (3,4)                0                1                1
# 255  (1,0) -> (1,1)                0                1                1
# 256  (0,2) -> (0,3)                0                1                1
#
#      Edge_Owner_5060  Edge_Owner_5262  Edge_Owner_5464  Edge_Owner_6171  \
# 0                 -1               -1               -1                1
# 1                  0               -1               -1                1
# 2                 -1                0               -1                1
# 3                 -1               -1                0                1
# 4                  1               -1                1                1
# ..               ...              ...              ...              ...
# 252                1                1                1                0
# 253                1                1                1                0
# 254                1                1                1                0
# 255                1                1                1                0
# 256                1                1                1                0
#
#      Edge_Owner_6373  Edge_Owner_6575  ...  Cell_Owner_63  Cell_Edge_Count_63  \
# 0                 -1                1  ...             -1                   2
# 1                 -1                1  ...             -1                   2
# 2                 -1                1  ...             -1                   2
# 3                 -1                1  ...             -1                   2
# 4                 -1                1  ...             -1                   2
# ..               ...              ...  ...            ...                 ...
# 252                0                0  ...              1                   4
# 253                0                0  ...              1                   4
# 254                0                0  ...              1                   4
# 255                0                0  ...              1                   4
# 256                0                0  ...              1                   4
#
#      Cell_Owner_20  Cell_Edge_Count_20  Cell_Owner_64  Cell_Edge_Count_64  \
# 0                0                   4             -1                   2
# 1                0                   4             -1                   2
# 2                0                   4             -1                   3
# 3                0                   4             -1                   2
# 4                0                   4             -1                   2
# ..             ...                 ...            ...                 ...
# 252             -1                   3              1                   4
# 253             -1                   2              1                   4
# 254             -1                   2              1                   4
# 255              0                   4              1                   4
# 256             -1                   2              1                   4
#
#      Cell_Owner_21  Cell_Edge_Count_21  Cell_Owner_22  Cell_Edge_Count_22
# 0                0                   4              0                   4
# 1                0                   4              0                   4
# 2                0                   4              0                   4
# 3                0                   4              0                   4
# 4                0                   4              0                   4
# ..             ...                 ...            ...                 ...
# 252              1                   4             -1                   3
# 253              1                   4             -1                   2
# 254              1                   4             -1                   3
# 255              1                   4             -1                   2
# 256              1                   4             -1                   2
#
# [88241 rows x 153 columns]

# %%
df = df[df.columns.drop(list(df.filter(regex='Edge_Owner_')))]

# %%
X = df.drop(columns=['Action'])
y = df['Action']

# Max leaf is the number of action
max_leaf = len(df['Action'].unique())
features = X.columns

# %%
clf = DecisionTreeClassifier(max_leaf_nodes=max_leaf, random_state=42)
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=82, random_state=42)

# %%
text_representation = tree.export_text(clf, feature_names=list(features))
print(text_representation)
# Out:
# |--- Cell_Edge_Count_02 <= 3.50
# |   |--- Cell_Owner_21 <= -0.50
# |   |   |--- Cell_Owner_63 <= -0.50
# |   |   |   |--- Cell_Edge_Count_01 <= 2.50
# |   |   |   |   |--- Cell_Owner_51 <= 0.50
# |   |   |   |   |   |--- Cell_Owner_31 <= 0.50
# |   |   |   |   |   |   |--- class: (0,1) -> (0,2)
# |   |   |   |   |   |--- Cell_Owner_31 >  0.50
# |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |--- Cell_Owner_51 >  0.50
# |   |   |   |   |   |--- class: (0,1) -> (0,2)
# |   |   |   |--- Cell_Edge_Count_01 >  2.50
# |   |   |   |   |--- Cell_Owner_12 <= 0.50
# |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |   |--- Cell_Owner_12 >  0.50
# |   |   |   |   |   |--- class: (1,4) -> (1,5)
# |   |   |--- Cell_Owner_63 >  -0.50
# |   |   |   |--- Cell_Edge_Count_14 <= 3.50
# |   |   |   |   |--- Cell_Owner_64 <= -0.50
# |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |   |--- Cell_Owner_64 >  -0.50
# |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |--- Cell_Edge_Count_14 >  3.50
# |   |   |   |   |--- class: (0,2) -> (0,3)
# |   |--- Cell_Owner_21 >  -0.50
# |   |   |--- Cell_Owner_03 <= 0.50
# |   |   |   |--- Cell_Owner_04 <= -0.50
# |   |   |   |   |--- Cell_Owner_34 <= -0.50
# |   |   |   |   |   |--- Cell_Edge_Count_31 <= 3.50
# |   |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |   |   |--- Cell_Edge_Count_31 >  3.50
# |   |   |   |   |   |   |--- Cell_Edge_Count_54 <= 3.50
# |   |   |   |   |   |   |   |--- Cell_Owner_14 <= 0.50
# |   |   |   |   |   |   |   |   |--- Cell_Owner_23 <= -0.50
# |   |   |   |   |   |   |   |   |   |--- Cell_Edge_Count_22 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |   |   |   |   |   |   |--- Cell_Edge_Count_22 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: (0,4) -> (0,5)
# |   |   |   |   |   |   |   |   |--- Cell_Owner_23 >  -0.50
# |   |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |   |--- Cell_Owner_14 >  0.50
# |   |   |   |   |   |   |   |   |--- class: (5,2) -> (6,2)
# |   |   |   |   |   |   |--- Cell_Edge_Count_54 >  3.50
# |   |   |   |   |   |   |   |--- Cell_Edge_Count_51 <= 3.50
# |   |   |   |   |   |   |   |   |--- class: (4,4) -> (4,5)
# |   |   |   |   |   |   |   |--- Cell_Edge_Count_51 >  3.50
# |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |--- Cell_Owner_34 >  -0.50
# |   |   |   |   |   |--- Cell_Edge_Count_20 <= 3.50
# |   |   |   |   |   |   |--- Cell_Owner_34 <= 0.50
# |   |   |   |   |   |   |   |--- class: (0,2) -> (0,3)
# |   |   |   |   |   |   |--- Cell_Owner_34 >  0.50
# |   |   |   |   |   |   |   |--- Cell_Owner_31 <= 0.50
# |   |   |   |   |   |   |   |   |--- Cell_Edge_Count_43 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |   |   |--- Cell_Edge_Count_43 >  3.50
# |   |   |   |   |   |   |   |   |   |--- class: (3,1) -> (4,1)
# |   |   |   |   |   |   |   |--- Cell_Owner_31 >  0.50
# |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |--- Cell_Edge_Count_20 >  3.50
# |   |   |   |   |   |   |--- Cell_Owner_50 <= -0.50
# |   |   |   |   |   |   |   |--- Cell_Owner_51 <= -0.50
# |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |   |--- Cell_Owner_51 >  -0.50
# |   |   |   |   |   |   |   |   |--- class: (5,0) -> (6,0)
# |   |   |   |   |   |   |--- Cell_Owner_50 >  -0.50
# |   |   |   |   |   |   |   |--- class: (0,2) -> (1,2)
# |   |   |   |--- Cell_Owner_04 >  -0.50
# |   |   |   |   |--- Cell_Owner_00 <= 0.50
# |   |   |   |   |   |--- Cell_Owner_01 <= -0.50
# |   |   |   |   |   |   |--- Cell_Owner_04 <= 0.50
# |   |   |   |   |   |   |   |--- Cell_Edge_Count_63 <= 3.50
# |   |   |   |   |   |   |   |   |--- Cell_Edge_Count_50 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- class: (0,2) -> (0,3)
# |   |   |   |   |   |   |   |   |--- Cell_Edge_Count_50 >  3.50
# |   |   |   |   |   |   |   |   |   |--- class: (6,3) -> (7,3)
# |   |   |   |   |   |   |   |--- Cell_Edge_Count_63 >  3.50
# |   |   |   |   |   |   |   |   |--- class: (0,3) -> (1,3)
# |   |   |   |   |   |   |--- Cell_Owner_04 >  0.50
# |   |   |   |   |   |   |   |--- Cell_Owner_41 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |   |--- Cell_Owner_41 >  0.50
# |   |   |   |   |   |   |   |   |--- class: (0,0) -> (1,0)
# |   |   |   |   |   |--- Cell_Owner_01 >  -0.50
# |   |   |   |   |   |   |--- Cell_Owner_12 <= -0.50
# |   |   |   |   |   |   |   |--- Cell_Edge_Count_12 <= 2.50
# |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |   |--- Cell_Edge_Count_12 >  2.50
# |   |   |   |   |   |   |   |   |--- class: (1,2) -> (1,3)
# |   |   |   |   |   |   |--- Cell_Owner_12 >  -0.50
# |   |   |   |   |   |   |   |--- Cell_Owner_11 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: (0,2) -> (0,3)
# |   |   |   |   |   |   |   |--- Cell_Owner_11 >  0.50
# |   |   |   |   |   |   |   |   |--- class: (0,2) -> (0,3)
# |   |   |   |   |--- Cell_Owner_00 >  0.50
# |   |   |   |   |   |--- class: (5,0) -> (6,0)
# |   |   |--- Cell_Owner_03 >  0.50
# |   |   |   |--- Cell_Owner_54 <= 0.50
# |   |   |   |   |--- Cell_Edge_Count_11 <= 3.50
# |   |   |   |   |   |--- class: (5,0) -> (6,0)
# |   |   |   |   |--- Cell_Edge_Count_11 >  3.50
# |   |   |   |   |   |--- Cell_Owner_60 <= 0.50
# |   |   |   |   |   |   |--- class: (0,2) -> (1,2)
# |   |   |   |   |   |--- Cell_Owner_60 >  0.50
# |   |   |   |   |   |   |--- class: (0,2) -> (1,2)
# |   |   |   |--- Cell_Owner_54 >  0.50
# |   |   |   |   |--- Cell_Owner_44 <= 0.50
# |   |   |   |   |   |--- Cell_Owner_01 <= 0.50
# |   |   |   |   |   |   |--- class: (0,2) -> (0,3)
# |   |   |   |   |   |--- Cell_Owner_01 >  0.50
# |   |   |   |   |   |   |--- class: (0,0) -> (1,0)
# |   |   |   |   |--- Cell_Owner_44 >  0.50
# |   |   |   |   |   |--- Cell_Owner_22 <= 0.50
# |   |   |   |   |   |   |--- class: (0,2) -> (1,2)
# |   |   |   |   |   |--- Cell_Owner_22 >  0.50
# |   |   |   |   |   |   |--- Cell_Owner_12 <= 0.50
# |   |   |   |   |   |   |   |--- class: (1,2) -> (1,3)
# |   |   |   |   |   |   |--- Cell_Owner_12 >  0.50
# |   |   |   |   |   |   |   |--- class: (0,2) -> (1,2)
# |--- Cell_Edge_Count_02 >  3.50
# |   |--- Cell_Edge_Count_03 <= 3.50
# |   |   |--- Cell_Owner_40 <= -0.50
# |   |   |   |--- Cell_Edge_Count_61 <= 3.50
# |   |   |   |   |--- Cell_Owner_01 <= -0.50
# |   |   |   |   |   |--- class: (0,1) -> (0,2)
# |   |   |   |   |--- Cell_Owner_01 >  -0.50
# |   |   |   |   |   |--- Cell_Edge_Count_43 <= 2.50
# |   |   |   |   |   |   |--- class: (0,4) -> (1,4)
# |   |   |   |   |   |--- Cell_Edge_Count_43 >  2.50
# |   |   |   |   |   |   |--- class: (0,4) -> (0,5)
# |   |   |   |--- Cell_Edge_Count_61 >  3.50
# |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |--- Cell_Owner_40 >  -0.50
# |   |   |   |--- Cell_Owner_53 <= 0.50
# |   |   |   |   |--- Cell_Owner_04 <= -0.50
# |   |   |   |   |   |--- Cell_Owner_60 <= 0.50
# |   |   |   |   |   |   |--- Cell_Edge_Count_14 <= 3.50
# |   |   |   |   |   |   |   |--- class: (0,1) -> (1,1)
# |   |   |   |   |   |   |--- Cell_Edge_Count_14 >  3.50
# |   |   |   |   |   |   |   |--- class: (0,4) -> (1,4)
# |   |   |   |   |   |--- Cell_Owner_60 >  0.50
# |   |   |   |   |   |   |--- class: (0,4) -> (1,4)
# |   |   |   |   |--- Cell_Owner_04 >  -0.50
# |   |   |   |   |   |--- Cell_Owner_01 <= -0.50
# |   |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |   |   |--- Cell_Owner_01 >  -0.50
# |   |   |   |   |   |   |--- Cell_Owner_00 <= -0.50
# |   |   |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |   |   |   |--- Cell_Owner_00 >  -0.50
# |   |   |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |--- Cell_Owner_53 >  0.50
# |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |--- Cell_Edge_Count_03 >  3.50
# |   |   |--- Cell_Edge_Count_04 <= 3.50
# |   |   |   |--- Cell_Edge_Count_51 <= 3.50
# |   |   |   |   |--- Cell_Owner_03 <= 0.50
# |   |   |   |   |   |--- Cell_Edge_Count_60 <= 3.50
# |   |   |   |   |   |   |--- Cell_Edge_Count_53 <= 3.50
# |   |   |   |   |   |   |   |--- class: (5,3) -> (6,3)
# |   |   |   |   |   |   |--- Cell_Edge_Count_53 >  3.50
# |   |   |   |   |   |   |   |--- class: (5,1) -> (6,1)
# |   |   |   |   |   |--- Cell_Edge_Count_60 >  3.50
# |   |   |   |   |   |   |--- Cell_Edge_Count_40 <= 3.50
# |   |   |   |   |   |   |   |--- class: (5,1) -> (6,1)
# |   |   |   |   |   |   |--- Cell_Edge_Count_40 >  3.50
# |   |   |   |   |   |   |   |--- class: (5,0) -> (6,0)
# |   |   |   |   |--- Cell_Owner_03 >  0.50
# |   |   |   |   |   |--- Cell_Owner_54 <= 0.50
# |   |   |   |   |   |   |--- Cell_Owner_62 <= 0.50
# |   |   |   |   |   |   |   |--- class: (1,4) -> (1,5)
# |   |   |   |   |   |   |--- Cell_Owner_62 >  0.50
# |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |--- Cell_Owner_54 >  0.50
# |   |   |   |   |   |   |--- class: (5,2) -> (6,2)
# |   |   |   |--- Cell_Edge_Count_51 >  3.50
# |   |   |   |   |--- Cell_Owner_61 <= 0.50
# |   |   |   |   |   |--- Cell_Edge_Count_13 <= 3.50
# |   |   |   |   |   |   |--- class: (6,4) -> (6,5)
# |   |   |   |   |   |--- Cell_Edge_Count_13 >  3.50
# |   |   |   |   |   |   |--- class: (0,4) -> (0,5)
# |   |   |   |   |--- Cell_Owner_61 >  0.50
# |   |   |   |   |   |--- Cell_Owner_62 <= -0.50
# |   |   |   |   |   |   |--- class: (5,4) -> (6,4)
# |   |   |   |   |   |--- Cell_Owner_62 >  -0.50
# |   |   |   |   |   |   |--- class: (6,5) -> (7,5)
# |   |   |--- Cell_Edge_Count_04 >  3.50
# |   |   |   |--- Cell_Owner_52 <= 0.50
# |   |   |   |   |--- Cell_Owner_54 <= -0.50
# |   |   |   |   |   |--- Cell_Owner_31 <= -0.50
# |   |   |   |   |   |   |--- Cell_Owner_10 <= -0.50
# |   |   |   |   |   |   |   |--- class: (1,0) -> (2,0)
# |   |   |   |   |   |   |--- Cell_Owner_10 >  -0.50
# |   |   |   |   |   |   |   |--- Cell_Owner_22 <= -0.50
# |   |   |   |   |   |   |   |   |--- class: (2,2) -> (3,2)
# |   |   |   |   |   |   |   |--- Cell_Owner_22 >  -0.50
# |   |   |   |   |   |   |   |   |--- class: (5,4) -> (6,4)
# |   |   |   |   |   |--- Cell_Owner_31 >  -0.50
# |   |   |   |   |   |   |--- Cell_Edge_Count_50 <= 3.50
# |   |   |   |   |   |   |   |--- class: (5,0) -> (6,0)
# |   |   |   |   |   |   |--- Cell_Edge_Count_50 >  3.50
# |   |   |   |   |   |   |   |--- class: (5,4) -> (6,4)
# |   |   |   |   |--- Cell_Owner_54 >  -0.50
# |   |   |   |   |   |--- Cell_Owner_41 <= -0.50
# |   |   |   |   |   |   |--- Cell_Owner_51 <= -0.50
# |   |   |   |   |   |   |   |--- Cell_Owner_10 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: (5,0) -> (6,0)
# |   |   |   |   |   |   |   |--- Cell_Owner_10 >  0.50
# |   |   |   |   |   |   |   |   |--- class: (5,1) -> (6,1)
# |   |   |   |   |   |   |--- Cell_Owner_51 >  -0.50
# |   |   |   |   |   |   |   |--- class: (4,1) -> (5,1)
# |   |   |   |   |   |--- Cell_Owner_41 >  -0.50
# |   |   |   |   |   |   |--- class: (4,0) -> (5,0)
# |   |   |   |--- Cell_Owner_52 >  0.50
# |   |   |   |   |--- Cell_Owner_11 <= 0.50
# |   |   |   |   |   |--- Cell_Owner_14 <= 0.50
# |   |   |   |   |   |   |--- Cell_Owner_10 <= 0.50
# |   |   |   |   |   |   |   |--- class: (5,0) -> (6,0)
# |   |   |   |   |   |   |--- Cell_Owner_10 >  0.50
# |   |   |   |   |   |   |   |--- class: (0,1) -> (1,1)
# |   |   |   |   |   |--- Cell_Owner_14 >  0.50
# |   |   |   |   |   |   |--- Cell_Owner_44 <= 0.50
# |   |   |   |   |   |   |   |--- Cell_Owner_13 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: (0,0) -> (1,0)
# |   |   |   |   |   |   |   |--- Cell_Owner_13 >  0.50
# |   |   |   |   |   |   |   |   |--- class: (0,0) -> (1,0)
# |   |   |   |   |   |   |--- Cell_Owner_44 >  0.50
# |   |   |   |   |   |   |   |--- class: (1,1) -> (2,1)
# |   |   |   |   |--- Cell_Owner_11 >  0.50
# |   |   |   |   |   |--- Cell_Owner_13 <= 0.50
# |   |   |   |   |   |   |--- Cell_Owner_00 <= 0.50
# |   |   |   |   |   |   |   |--- class: (1,0) -> (1,1)
# |   |   |   |   |   |   |--- Cell_Owner_00 >  0.50
# |   |   |   |   |   |   |   |--- class: (3,4) -> (4,4)
# |   |   |   |   |   |--- Cell_Owner_13 >  0.50
# |   |   |   |   |   |   |--- Cell_Owner_60 <= 0.50
# |   |   |   |   |   |   |   |--- class: (6,1) -> (7,1)
# |   |   |   |   |   |   |--- Cell_Owner_60 >  0.50
# |   |   |   |   |   |   |   |--- Cell_Owner_22 <= 0.50
# |   |   |   |   |   |   |   |   |--- Cell_Owner_23 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: (3,3) -> (3,4)
# |   |   |   |   |   |   |   |   |--- Cell_Owner_23 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: (5,5) -> (6,5)
# |   |   |   |   |   |   |   |--- Cell_Owner_22 >  0.50
# |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)

# %%
action_decisions = []
current_action_set = []

n_nodes = clf.tree_.node_count
children_left = clf.tree_.children_left
children_right = clf.tree_.children_right
feature = clf.tree_.feature
threshold = clf.tree_.threshold

def retrieve_tree(tree, classes, node_id):
    is_split_node = tree.children_left[node_id] != tree.children_right[node_id]
    
    current_action_set.append(features[tree.feature[node_id]])
    
    if is_split_node:
        retrieve_tree(tree, classes, children_left[node_id])
        retrieve_tree(tree, classes, children_right[node_id])
    else:
        action_decisions.append(current_action_set + [classes[np.array(tree.value[node_id][0]).argmax()]])
        
    current_action_set.pop()

retrieve_tree(clf.tree_, clf.classes_, 0)

# %%
action_feature_dict = defaultdict(list)

for action_decision in action_decisions:
    action_feature_dict[action_decision[-1]].append(action_decision[: -1])
    
for action_name, features in action_feature_dict.items():
    feature_set = set()
    for feature_list in features:
        for feature in feature_list:
            feature_set.add(feature)
        
    print(f"Action Name: {action_name}")
    print(f"Feature List: [{', '.join(list(feature_set))}]")
    print(f"Paths({len(features)}):")
    for idx, feature_list in enumerate(features, 1):
        print(f"\tPath {idx}: {', '.join(feature_list)}")
    print("-" * 115)
    
print("The excluded action list:\n\t", end='')
print('\n\t'.join(set(df['Action'].unique()) ^ set(action_feature_dict.keys())))
# Out:
# Action Name: (0,1) -> (0,2)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_63, Cell_Owner_51, Cell_Owner_22, Cell_Edge_Count_01, Cell_Owner_01, Cell_Edge_Count_02, Cell_Owner_40, Cell_Owner_21, Cell_Owner_31, Cell_Edge_Count_61]
# Paths(3):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_63, Cell_Edge_Count_01, Cell_Owner_51, Cell_Owner_31, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_63, Cell_Edge_Count_01, Cell_Owner_51, Cell_Owner_22
# 	Path 3: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Owner_40, Cell_Edge_Count_61, Cell_Owner_01, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,0) -> (0,1)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_04, Cell_Owner_14, Cell_Edge_Count_20, Cell_Edge_Count_14, Cell_Edge_Count_02, Cell_Owner_52, Cell_Edge_Count_04, Cell_Edge_Count_43, Cell_Owner_03, Cell_Owner_60, Cell_Edge_Count_61, Cell_Owner_53, Cell_Owner_11, Cell_Owner_63, Cell_Owner_51, Cell_Owner_01, Cell_Owner_40, Cell_Owner_54, Cell_Owner_62, Cell_Owner_50, Cell_Owner_13, Cell_Edge_Count_31, Cell_Edge_Count_54, Cell_Owner_64, Cell_Owner_21, Cell_Owner_31, Cell_Owner_00, Cell_Owner_12, Cell_Owner_41, Cell_Owner_22, Cell_Owner_34, Cell_Edge_Count_01, Cell_Edge_Count_12, Cell_Edge_Count_51, Cell_Owner_23]
# Paths(13):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_63, Cell_Edge_Count_01, Cell_Owner_51, Cell_Owner_31, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_63, Cell_Edge_Count_14, Cell_Owner_64, Cell_Owner_22
# 	Path 3: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_31, Cell_Edge_Count_54, Cell_Owner_14, Cell_Owner_23, Cell_Owner_22
# 	Path 4: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_31, Cell_Edge_Count_54, Cell_Edge_Count_51, Cell_Owner_22
# 	Path 5: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_20, Cell_Owner_34, Cell_Owner_31, Cell_Edge_Count_43, Cell_Owner_22
# 	Path 6: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_20, Cell_Owner_34, Cell_Owner_31, Cell_Owner_22
# 	Path 7: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_20, Cell_Owner_50, Cell_Owner_51, Cell_Owner_22
# 	Path 8: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_00, Cell_Owner_01, Cell_Owner_04, Cell_Owner_41, Cell_Owner_22
# 	Path 9: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_00, Cell_Owner_01, Cell_Owner_12, Cell_Edge_Count_12, Cell_Owner_22
# 	Path 10: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Owner_40, Cell_Edge_Count_61, Cell_Owner_22
# 	Path 11: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Owner_40, Cell_Owner_53, Cell_Owner_22
# 	Path 12: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Edge_Count_51, Cell_Owner_03, Cell_Owner_54, Cell_Owner_62, Cell_Owner_22
# 	Path 13: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_11, Cell_Owner_13, Cell_Owner_60, Cell_Owner_22, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,3) -> (0,4)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_04, Cell_Owner_14, Cell_Edge_Count_14, Cell_Edge_Count_02, Cell_Owner_03, Cell_Owner_53, Cell_Owner_63, Cell_Owner_01, Cell_Owner_40, Cell_Edge_Count_22, Cell_Edge_Count_31, Cell_Edge_Count_54, Cell_Owner_64, Cell_Owner_21, Cell_Owner_00, Cell_Owner_12, Cell_Owner_22, Cell_Owner_34, Cell_Edge_Count_01, Cell_Owner_23]
# Paths(7):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_63, Cell_Edge_Count_01, Cell_Owner_12, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_63, Cell_Edge_Count_14, Cell_Owner_64, Cell_Owner_22
# 	Path 3: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_31, Cell_Owner_22
# 	Path 4: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_31, Cell_Edge_Count_54, Cell_Owner_14, Cell_Owner_23, Cell_Edge_Count_22, Cell_Owner_22
# 	Path 5: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Owner_40, Cell_Owner_53, Cell_Owner_04, Cell_Owner_01, Cell_Owner_22
# 	Path 6: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Owner_40, Cell_Owner_53, Cell_Owner_04, Cell_Owner_01, Cell_Owner_00, Cell_Owner_22
# 	Path 7: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Owner_40, Cell_Owner_53, Cell_Owner_04, Cell_Owner_01, Cell_Owner_00, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (1,4) -> (1,5)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_63, Cell_Owner_22, Cell_Edge_Count_01, Cell_Edge_Count_02, Cell_Edge_Count_51, Cell_Edge_Count_04, Cell_Owner_21, Cell_Owner_54, Cell_Owner_62, Cell_Owner_03, Cell_Owner_12]
# Paths(2):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_63, Cell_Edge_Count_01, Cell_Owner_12, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Edge_Count_51, Cell_Owner_03, Cell_Owner_54, Cell_Owner_62, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,2) -> (0,3)
# Feature List: [Cell_Edge_Count_50, Cell_Owner_63, Cell_Owner_22, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_20, Cell_Edge_Count_14, Cell_Owner_11, Cell_Owner_01, Cell_Edge_Count_02, Cell_Owner_54, Cell_Owner_21, Cell_Owner_44, Cell_Owner_03, Cell_Edge_Count_63, Cell_Owner_00, Cell_Owner_12]
# Paths(6):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_63, Cell_Edge_Count_14, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_20, Cell_Owner_34, Cell_Owner_22
# 	Path 3: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_00, Cell_Owner_01, Cell_Owner_04, Cell_Edge_Count_63, Cell_Edge_Count_50, Cell_Owner_22
# 	Path 4: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_00, Cell_Owner_01, Cell_Owner_12, Cell_Owner_11, Cell_Owner_22
# 	Path 5: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_00, Cell_Owner_01, Cell_Owner_12, Cell_Owner_11, Cell_Owner_22
# 	Path 6: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_54, Cell_Owner_44, Cell_Owner_01, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,4) -> (0,5)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_04, Cell_Owner_14, Cell_Edge_Count_13, Cell_Edge_Count_02, Cell_Edge_Count_04, Cell_Edge_Count_43, Cell_Owner_03, Cell_Edge_Count_61, Cell_Owner_61, Cell_Owner_01, Cell_Owner_40, Cell_Edge_Count_22, Cell_Edge_Count_31, Cell_Edge_Count_54, Cell_Owner_21, Cell_Owner_22, Cell_Owner_34, Cell_Edge_Count_51, Cell_Owner_23]
# Paths(3):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_31, Cell_Edge_Count_54, Cell_Owner_14, Cell_Owner_23, Cell_Edge_Count_22, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Owner_40, Cell_Edge_Count_61, Cell_Owner_01, Cell_Edge_Count_43, Cell_Owner_22
# 	Path 3: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Edge_Count_51, Cell_Owner_61, Cell_Edge_Count_13, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (5,2) -> (6,2)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_04, Cell_Edge_Count_31, Cell_Owner_34, Cell_Owner_14, Cell_Owner_22, Cell_Edge_Count_02, Cell_Edge_Count_51, Cell_Edge_Count_54, Cell_Edge_Count_04, Cell_Owner_21, Cell_Owner_54, Cell_Owner_03]
# Paths(2):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_31, Cell_Edge_Count_54, Cell_Owner_14, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Edge_Count_51, Cell_Owner_03, Cell_Owner_54, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (4,4) -> (4,5)
# Feature List: [Cell_Owner_04, Cell_Edge_Count_31, Cell_Owner_34, Cell_Owner_22, Cell_Edge_Count_02, Cell_Edge_Count_51, Cell_Edge_Count_54, Cell_Owner_21, Cell_Owner_03]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_31, Cell_Edge_Count_54, Cell_Edge_Count_51, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (3,1) -> (4,1)
# Feature List: [Cell_Owner_04, Cell_Edge_Count_20, Cell_Owner_34, Cell_Owner_22, Cell_Edge_Count_43, Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_31, Cell_Owner_03]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_20, Cell_Owner_34, Cell_Owner_31, Cell_Edge_Count_43, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (5,0) -> (6,0)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_04, Cell_Edge_Count_20, Cell_Owner_14, Cell_Edge_Count_02, Cell_Owner_52, Cell_Edge_Count_04, Cell_Owner_03, Cell_Owner_11, Cell_Owner_51, Cell_Owner_54, Cell_Owner_50, Cell_Edge_Count_60, Cell_Owner_10, Cell_Edge_Count_40, Cell_Owner_21, Cell_Owner_31, Cell_Owner_00, Cell_Owner_41, Cell_Edge_Count_50, Cell_Owner_22, Cell_Owner_34, Cell_Edge_Count_51, Cell_Edge_Count_11]
# Paths(7):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_20, Cell_Owner_50, Cell_Owner_51, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_00, Cell_Owner_22
# 	Path 3: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_54, Cell_Edge_Count_11, Cell_Owner_22
# 	Path 4: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Edge_Count_51, Cell_Owner_03, Cell_Edge_Count_60, Cell_Edge_Count_40, Cell_Owner_22
# 	Path 5: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_54, Cell_Owner_31, Cell_Edge_Count_50, Cell_Owner_22
# 	Path 6: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_54, Cell_Owner_41, Cell_Owner_51, Cell_Owner_10, Cell_Owner_22
# 	Path 7: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_11, Cell_Owner_14, Cell_Owner_10, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,2) -> (1,2)
# Feature List: [Cell_Owner_04, Cell_Edge_Count_20, Cell_Owner_34, Cell_Owner_22, Cell_Edge_Count_02, Cell_Edge_Count_11, Cell_Owner_54, Cell_Owner_21, Cell_Owner_44, Cell_Owner_50, Cell_Owner_60, Cell_Owner_03, Cell_Owner_12]
# Paths(5):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_34, Cell_Edge_Count_20, Cell_Owner_50, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_54, Cell_Edge_Count_11, Cell_Owner_60, Cell_Owner_22
# 	Path 3: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_54, Cell_Edge_Count_11, Cell_Owner_60, Cell_Owner_22
# 	Path 4: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_54, Cell_Owner_44, Cell_Owner_22, Cell_Owner_22
# 	Path 5: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_54, Cell_Owner_44, Cell_Owner_22, Cell_Owner_12, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (6,3) -> (7,3)
# Feature List: [Cell_Edge_Count_50, Cell_Owner_04, Cell_Owner_22, Cell_Owner_01, Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Edge_Count_63, Cell_Owner_00]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_00, Cell_Owner_01, Cell_Owner_04, Cell_Edge_Count_63, Cell_Edge_Count_50, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,3) -> (1,3)
# Feature List: [Cell_Owner_04, Cell_Owner_22, Cell_Owner_01, Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Edge_Count_63, Cell_Owner_00]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_00, Cell_Owner_01, Cell_Owner_04, Cell_Edge_Count_63, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,0) -> (1,0)
# Feature List: [Cell_Owner_13, Cell_Edge_Count_03, Cell_Owner_04, Cell_Owner_22, Cell_Owner_14, Cell_Owner_01, Cell_Edge_Count_02, Cell_Owner_52, Cell_Owner_54, Cell_Owner_21, Cell_Owner_44, Cell_Edge_Count_04, Cell_Owner_03, Cell_Owner_00, Cell_Owner_11, Cell_Owner_41]
# Paths(4):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_00, Cell_Owner_01, Cell_Owner_04, Cell_Owner_41, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_54, Cell_Owner_44, Cell_Owner_01, Cell_Owner_22
# 	Path 3: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_11, Cell_Owner_14, Cell_Owner_44, Cell_Owner_13, Cell_Owner_22
# 	Path 4: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_11, Cell_Owner_14, Cell_Owner_44, Cell_Owner_13, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (1,2) -> (1,3)
# Feature List: [Cell_Owner_04, Cell_Owner_22, Cell_Edge_Count_12, Cell_Owner_01, Cell_Edge_Count_02, Cell_Owner_54, Cell_Owner_21, Cell_Owner_44, Cell_Owner_03, Cell_Owner_00, Cell_Owner_12]
# Paths(2):
# 	Path 1: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_04, Cell_Owner_00, Cell_Owner_01, Cell_Owner_12, Cell_Edge_Count_12, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Owner_21, Cell_Owner_03, Cell_Owner_54, Cell_Owner_44, Cell_Owner_22, Cell_Owner_12, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,4) -> (1,4)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_22, Cell_Owner_04, Cell_Edge_Count_14, Cell_Owner_01, Cell_Edge_Count_02, Cell_Owner_40, Cell_Edge_Count_43, Cell_Owner_53, Cell_Edge_Count_61, Cell_Owner_60]
# Paths(3):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Owner_40, Cell_Edge_Count_61, Cell_Owner_01, Cell_Edge_Count_43, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Owner_40, Cell_Owner_53, Cell_Owner_04, Cell_Owner_60, Cell_Edge_Count_14, Cell_Owner_22
# 	Path 3: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Owner_40, Cell_Owner_53, Cell_Owner_04, Cell_Owner_60, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,1) -> (1,1)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_04, Cell_Owner_22, Cell_Owner_14, Cell_Owner_10, Cell_Edge_Count_14, Cell_Owner_11, Cell_Edge_Count_02, Cell_Owner_52, Cell_Owner_40, Cell_Edge_Count_04, Cell_Owner_60, Cell_Owner_53]
# Paths(2):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Owner_40, Cell_Owner_53, Cell_Owner_04, Cell_Owner_60, Cell_Edge_Count_14, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_11, Cell_Owner_14, Cell_Owner_10, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (5,3) -> (6,3)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_22, Cell_Edge_Count_53, Cell_Edge_Count_51, Cell_Edge_Count_02, Cell_Edge_Count_04, Cell_Owner_03, Cell_Edge_Count_60]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Edge_Count_51, Cell_Owner_03, Cell_Edge_Count_60, Cell_Edge_Count_53, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (5,1) -> (6,1)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_22, Cell_Owner_51, Cell_Edge_Count_53, Cell_Edge_Count_40, Cell_Owner_10, Cell_Owner_41, Cell_Edge_Count_51, Cell_Edge_Count_02, Cell_Owner_52, Cell_Edge_Count_04, Cell_Owner_54, Cell_Owner_03, Cell_Edge_Count_60]
# Paths(3):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Edge_Count_51, Cell_Owner_03, Cell_Edge_Count_60, Cell_Edge_Count_53, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Edge_Count_51, Cell_Owner_03, Cell_Edge_Count_60, Cell_Edge_Count_40, Cell_Owner_22
# 	Path 3: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_54, Cell_Owner_41, Cell_Owner_51, Cell_Owner_10, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (6,4) -> (6,5)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_22, Cell_Owner_61, Cell_Edge_Count_13, Cell_Edge_Count_51, Cell_Edge_Count_02, Cell_Edge_Count_04]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Edge_Count_51, Cell_Owner_61, Cell_Edge_Count_13, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (5,4) -> (6,4)
# Feature List: [Cell_Edge_Count_03, Cell_Edge_Count_50, Cell_Owner_22, Cell_Owner_10, Cell_Owner_61, Cell_Edge_Count_51, Cell_Edge_Count_02, Cell_Owner_52, Cell_Edge_Count_04, Cell_Owner_62, Cell_Owner_54, Cell_Owner_31]
# Paths(3):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Edge_Count_51, Cell_Owner_61, Cell_Owner_62, Cell_Owner_22
# 	Path 2: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_54, Cell_Owner_31, Cell_Owner_10, Cell_Owner_22, Cell_Owner_22
# 	Path 3: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_54, Cell_Owner_31, Cell_Edge_Count_50, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (6,5) -> (7,5)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_22, Cell_Owner_61, Cell_Edge_Count_51, Cell_Edge_Count_02, Cell_Edge_Count_04, Cell_Owner_62]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Edge_Count_51, Cell_Owner_61, Cell_Owner_62, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (1,0) -> (2,0)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_22, Cell_Owner_10, Cell_Owner_52, Cell_Edge_Count_02, Cell_Edge_Count_04, Cell_Owner_54, Cell_Owner_31]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_54, Cell_Owner_31, Cell_Owner_10, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (2,2) -> (3,2)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_22, Cell_Owner_10, Cell_Owner_52, Cell_Edge_Count_02, Cell_Edge_Count_04, Cell_Owner_54, Cell_Owner_31]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_54, Cell_Owner_31, Cell_Owner_10, Cell_Owner_22, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (4,1) -> (5,1)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_51, Cell_Owner_22, Cell_Owner_52, Cell_Edge_Count_02, Cell_Edge_Count_04, Cell_Owner_54, Cell_Owner_41]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_54, Cell_Owner_41, Cell_Owner_51, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (4,0) -> (5,0)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_22, Cell_Owner_52, Cell_Edge_Count_02, Cell_Edge_Count_04, Cell_Owner_54, Cell_Owner_41]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_54, Cell_Owner_41, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (1,1) -> (2,1)
# Feature List: [Cell_Edge_Count_03, Cell_Owner_14, Cell_Owner_22, Cell_Owner_52, Cell_Edge_Count_02, Cell_Edge_Count_04, Cell_Owner_44, Cell_Owner_11]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_11, Cell_Owner_14, Cell_Owner_44, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (1,0) -> (1,1)
# Feature List: [Cell_Owner_13, Cell_Edge_Count_03, Cell_Owner_22, Cell_Owner_52, Cell_Edge_Count_02, Cell_Edge_Count_04, Cell_Owner_00, Cell_Owner_11]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_11, Cell_Owner_13, Cell_Owner_00, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (3,4) -> (4,4)
# Feature List: [Cell_Owner_13, Cell_Edge_Count_03, Cell_Owner_22, Cell_Owner_52, Cell_Edge_Count_02, Cell_Edge_Count_04, Cell_Owner_00, Cell_Owner_11]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_11, Cell_Owner_13, Cell_Owner_00, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (6,1) -> (7,1)
# Feature List: [Cell_Owner_13, Cell_Edge_Count_03, Cell_Owner_22, Cell_Owner_52, Cell_Edge_Count_02, Cell_Edge_Count_04, Cell_Owner_60, Cell_Owner_11]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_11, Cell_Owner_13, Cell_Owner_60, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (3,3) -> (3,4)
# Feature List: [Cell_Owner_13, Cell_Edge_Count_03, Cell_Owner_22, Cell_Owner_52, Cell_Edge_Count_02, Cell_Edge_Count_04, Cell_Owner_60, Cell_Owner_23, Cell_Owner_11]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_11, Cell_Owner_13, Cell_Owner_60, Cell_Owner_22, Cell_Owner_23, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (5,5) -> (6,5)
# Feature List: [Cell_Owner_13, Cell_Edge_Count_03, Cell_Owner_22, Cell_Owner_52, Cell_Edge_Count_02, Cell_Edge_Count_04, Cell_Owner_60, Cell_Owner_23, Cell_Owner_11]
# Paths(1):
# 	Path 1: Cell_Edge_Count_02, Cell_Edge_Count_03, Cell_Edge_Count_04, Cell_Owner_52, Cell_Owner_11, Cell_Owner_13, Cell_Owner_60, Cell_Owner_22, Cell_Owner_23, Cell_Owner_22
# -------------------------------------------------------------------------------------------------------------------
# The excluded action list:
# 	(6,1) -> (6,2)
# 	(3,5) -> (4,5)
# 	(4,4) -> (5,4)
# 	(5,0) -> (5,1)
# 	(6,4) -> (7,4)
# 	(6,0) -> (7,0)
# 	(6,2) -> (7,2)
# 	(2,1) -> (2,2)
# 	(3,2) -> (3,3)
# 	(1,5) -> (2,5)
# 	(2,2) -> (2,3)
# 	(7,0) -> (7,1)
# 	(3,0) -> (4,0)
# 	(1,3) -> (1,4)
# 	(1,2) -> (2,2)
# 	(2,3) -> (2,4)
# 	(2,3) -> (3,3)
# 	(4,3) -> (4,4)
# 	(7,4) -> (7,5)
# 	(4,5) -> (5,5)
# 	(6,0) -> (6,1)
# 	(7,2) -> (7,3)
# 	(7,3) -> (7,4)
# 	(4,1) -> (4,2)
# 	(3,2) -> (4,2)
# 	(2,5) -> (3,5)
# 	(3,3) -> (4,3)
# 	(2,1) -> (3,1)
# 	(5,2) -> (5,3)
# 	(2,0) -> (3,0)
# 	(4,3) -> (5,3)
# 	(2,4) -> (2,5)
# 	(2,0) -> (2,1)
# 	(0,5) -> (1,5)
# 	(6,3) -> (6,4)
# 	(3,4) -> (3,5)
# 	(4,2) -> (5,2)
# 	(1,3) -> (2,3)
# 	(6,2) -> (6,3)
# 	(2,4) -> (3,4)
# 	(5,3) -> (5,4)
# 	(3,0) -> (3,1)
# 	(5,1) -> (5,2)
# 	(3,1) -> (3,2)
# 	(4,0) -> (4,1)
# 	(1,1) -> (1,2)
# 	(5,4) -> (5,5)
# 	(7,1) -> (7,2)
# 	(4,2) -> (4,3)
# 	(1,4) -> (2,4)

# %%
df.to_csv('DB_game_states.csv')

# %%
dfs = []

for i in os.listdir("DotsAndBoxes"):
    if i.split(".")[-1] != 'csv':
        continue
    print(i)
    dfs.append(load_data(f"DotsAndBoxes/{i}", visit_threshold=1))

df = pd.concat(dfs)
df
# Out:
# record_43.csv
# record_57.csv
# record_309.csv
# record_321.csv
# record_447.csv
# record_453.csv
# record_335.csv
# record_80.csv
# record_94.csv
# record_484.csv
# record_490.csv
# record_679.csv
# record_645.csv
# record_123.csv
# record_137.csv
# record_889.csv
# record_651.csv
# record_1077.csv
# record_862.csv
# record_1063.csv
# record_876.csv
# record_686.csv
# record_692.csv
# record_719.csv
# record_731.csv
# record_725.csv
# record_916.csv
# record_902.csv
# record_269.csv
# record_255.csv
# record_533.csv
# record_527.csv
# record_241.csv
# record_296.csv
# record_282.csv
# record_283.csv
# record_297.csv
# record_526.csv
# record_240.csv
# record_254.csv
# record_532.csv
# record_268.csv
# record_903.csv
# record_917.csv
# record_724.csv
# record_730.csv
# record_718.csv
# record_693.csv
# record_687.csv
# record_877.csv
# record_1062.csv
# record_863.csv
# record_1076.csv
# record_136.csv
# record_650.csv
# record_888.csv
# record_644.csv
# record_122.csv
# record_678.csv
# record_491.csv
# record_485.csv
# record_95.csv
# record_81.csv
# record_452.csv
# record_334.csv
# record_320.csv
# record_446.csv
# record_56.csv
# record_308.csv
# record_42.csv
# record_54.csv
# record_478.csv
# record_40.csv
# record_336.csv
# record_450.csv
# record_68.csv
# record_444.csv
# record_322.csv
# record_97.csv
# record_83.csv
# record_493.csv
# record_487.csv
# record_108.csv
# record_652.csv
# record_134.csv
# record_120.csv
# record_646.csv
# record_1060.csv
# record_875.csv
# record_1074.csv
# record_861.csv
# record_691.csv
# record_849.csv
# record_685.csv
# record_1048.csv
# record_726.csv
# record_732.csv
# record_901.csv
# record_915.csv
# record_929.csv
# record_518.csv
# record_242.csv
# record_524.csv
# record_530.csv
# record_256.csv
# record_281.csv
# record_295.csv
# record_294.csv
# record_280.csv
# record_531.csv
# record_257.csv
# record_243.csv
# record_525.csv
# record_519.csv
# record_928.csv
# record_914.csv
# record_900.csv
# record_733.csv
# record_727.csv
# record_1049.csv
# record_684.csv
# record_848.csv
# record_690.csv
# record_860.csv
# record_1075.csv
# record_874.csv
# record_1061.csv
# record_121.csv
# record_647.csv
# record_653.csv
# record_135.csv
# record_109.csv
# record_486.csv
# record_492.csv
# record_82.csv
# record_96.csv
# record_445.csv
# record_323.csv
# record_337.csv
# record_69.csv
# record_451.csv
# record_41.csv
# record_479.csv
# record_55.csv
# record_455.csv
# record_333.csv
# record_327.csv
# record_79.csv
# record_441.csv
# record_51.csv
# record_469.csv
# record_45.csv
# record_496.csv
# record_482.csv
# record_92.csv
# record_86.csv
# record_8.csv
# record_131.csv
# record_657.csv
# record_643.csv
# record_125.csv
# record_119.csv
# record_694.csv
# record_1059.csv
# record_680.csv
# record_858.csv
# record_1065.csv
# record_870.csv
# record_1071.csv
# record_864.csv
# record_723.csv
# record_737.csv
# record_938.csv
# record_904.csv
# record_910.csv
# record_521.csv
# record_247.csv
# record_253.csv
# record_535.csv
# record_509.csv
# record_284.csv
# record_290.csv
# record_291.csv
# record_285.csv
# record_508.csv
# record_252.csv
# record_534.csv
# record_520.csv
# record_246.csv
# record_911.csv
# record_905.csv
# record_939.csv
# record_736.csv
# record_722.csv
# record_865.csv
# record_1070.csv
# record_871.csv
# record_1064.csv
# record_859.csv
# record_681.csv
# record_1058.csv
# record_695.csv
# record_118.csv
# record_642.csv
# record_124.csv
# record_130.csv
# record_656.csv
# record_9.csv
# record_87.csv
# record_93.csv
# record_483.csv
# record_497.csv
# record_44.csv
# record_468.csv
# record_50.csv
# record_326.csv
# record_440.csv
# record_78.csv
# record_454.csv
# record_332.csv
# record_442.csv
# record_324.csv
# record_330.csv
# record_456.csv
# record_46.csv
# record_318.csv
# record_52.csv
# record_481.csv
# record_495.csv
# record_85.csv
# record_91.csv
# record_126.csv
# record_898.csv
# record_640.csv
# record_654.csv
# record_132.csv
# record_668.csv
# record_683.csv
# record_697.csv
# record_1072.csv
# record_867.csv
# record_1066.csv
# record_873.csv
# record_734.csv
# record_720.csv
# record_708.csv
# record_913.csv
# record_907.csv
# record_536.csv
# record_250.csv
# record_244.csv
# record_522.csv
# record_278.csv
# record_293.csv
# record_287.csv
# record_286.csv
# record_292.csv
# record_279.csv
# record_245.csv
# record_523.csv
# record_537.csv
# record_251.csv
# record_906.csv
# record_912.csv
# record_709.csv
# record_721.csv
# record_735.csv
# record_872.csv
# record_1067.csv
# record_866.csv
# record_1073.csv
# record_696.csv
# record_682.csv
# record_669.csv
# record_655.csv
# record_133.csv
# record_127.csv
# record_641.csv
# record_899.csv
# record_90.csv
# record_84.csv
# record_494.csv
# record_480.csv
# record_53.csv
# record_47.csv
# record_319.csv
# record_331.csv
# record_457.csv
# record_443.csv
# record_325.csv
# record_20.csv
# record_418.csv
# record_34.csv
# record_424.csv
# record_342.csv
# record_356.csv
# record_430.csv
# record_381.csv
# record_395.csv
# record_168.csv
# record_140.csv
# record_626.csv
# record_632.csv
# record_154.csv
# record_1014.csv
# record_801.csv
# record_1000.csv
# record_815.csv
# record_183.csv
# record_1028.csv
# record_829.csv
# record_197.csv
# record_752.csv
# record_746.csv
# record_975.csv
# record_961.csv
# record_949.csv
# record_791.csv
# record_785.csv
# record_578.csv
# record_550.csv
# record_236.csv
# record_222.csv
# record_544.csv
# record_593.csv
# record_587.csv
# record_586.csv
# record_592.csv
# record_223.csv
# record_545.csv
# record_551.csv
# record_237.csv
# record_579.csv
# record_784.csv
# record_790.csv
# record_948.csv
# record_960.csv
# record_974.csv
# record_747.csv
# record_753.csv
# record_828.csv
# record_196.csv
# record_182.csv
# record_1029.csv
# record_814.csv
# record_1001.csv
# record_800.csv
# record_1015.csv
# record_633.csv
# record_155.csv
# record_141.csv
# record_627.csv
# record_169.csv
# record_394.csv
# record_380.csv
# record_357.csv
# record_431.csv
# record_425.csv
# record_343.csv
# record_35.csv
# record_419.csv
# record_21.csv
# record_37.csv
# record_369.csv
# record_23.csv
# record_433.csv
# record_355.csv
# record_341.csv
# record_427.csv
# record_396.csv
# record_382.csv
# record_619.csv
# record_157.csv
# record_631.csv
# record_625.csv
# record_143.csv
# record_1003.csv
# record_816.csv
# record_1017.csv
# record_802.csv
# record_194.csv
# record_180.csv
# record_779.csv
# record_745.csv
# record_751.csv
# record_989.csv
# record_962.csv
# record_976.csv
# record_786.csv
# record_792.csv
# record_209.csv
# record_547.csv
# record_221.csv
# record_235.csv
# record_553.csv
# record_584.csv
# record_590.csv
# record_591.csv
# record_585.csv
# record_234.csv
# record_552.csv
# record_546.csv
# record_220.csv
# record_208.csv
# record_793.csv
# record_787.csv
# record_977.csv
# record_963.csv
# record_988.csv
# record_750.csv
# record_744.csv
# record_778.csv
# record_181.csv
# record_195.csv
# record_803.csv
# record_1016.csv
# record_817.csv
# record_1002.csv
# record_624.csv
# record_142.csv
# record_156.csv
# record_630.csv
# record_618.csv
# record_383.csv
# record_397.csv
# record_340.csv
# record_426.csv
# record_432.csv
# record_354.csv
# record_22.csv
# record_36.csv
# record_368.csv
# record_350.csv
# record_436.csv
# record_422.csv
# record_344.csv
# record_32.csv
# record_26.csv
# record_378.csv
# record_393.csv
# record_387.csv
# record_634.csv
# record_152.csv
# record_146.csv
# record_620.csv
# record_608.csv
# record_191.csv
# record_185.csv
# record_1006.csv
# record_813.csv
# record_1012.csv
# record_807.csv
# record_740.csv
# record_998.csv
# record_754.csv
# record_768.csv
# record_783.csv
# record_797.csv
# record_967.csv
# record_973.csv
# record_224.csv
# record_542.csv
# record_556.csv
# record_230.csv
# record_218.csv
# record_581.csv
# record_595.csv
# record_594.csv
# record_580.csv
# record_219.csv
# record_557.csv
# record_231.csv
# record_225.csv
# record_543.csv
# record_972.csv
# record_966.csv
# record_796.csv
# record_782.csv
# record_769.csv
# record_755.csv
# record_999.csv
# record_741.csv
# record_806.csv
# record_1013.csv
# record_812.csv
# record_1007.csv
# record_184.csv
# record_190.csv
# record_609.csv
# record_147.csv
# record_621.csv
# record_635.csv
# record_153.csv
# record_386.csv
# record_392.csv
# record_27.csv
# record_379.csv
# record_33.csv
# record_423.csv
# record_345.csv
# record_351.csv
# record_437.csv
# record_347.csv
# record_421.csv
# record_19.csv
# record_435.csv
# record_353.csv
# record_25.csv
# record_409.csv
# record_31.csv
# record_384.csv
# record_390.csv
# record_623.csv
# record_145.csv
# record_151.csv
# record_637.csv
# record_179.csv
# record_838.csv
# record_186.csv
# record_192.csv
# record_1039.csv
# record_1011.csv
# record_804.csv
# record_1005.csv
# record_810.csv
# record_757.csv
# record_743.csv
# record_794.csv
# record_958.csv
# record_780.csv
# record_970.csv
# record_964.csv
# record_233.csv
# record_555.csv
# record_541.csv
# record_227.csv
# record_569.csv
# record_596.csv
# record_582.csv
# record_583.csv
# record_597.csv
# record_568.csv
# record_540.csv
# record_226.csv
# record_232.csv
# record_554.csv
# record_965.csv
# record_971.csv
# record_781.csv
# record_959.csv
# record_795.csv
# record_742.csv
# record_756.csv
# record_811.csv
# record_1004.csv
# record_805.csv
# record_1010.csv
# record_193.csv
# record_1038.csv
# record_839.csv
# record_187.csv
# record_178.csv
# record_150.csv
# record_636.csv
# record_622.csv
# record_144.csv
# record_391.csv
# record_385.csv
# record_30.csv
# record_408.csv
# record_24.csv
# record_434.csv
# record_352.csv
# record_346.csv
# record_18.csv
# record_420.csv
# record_439.csv
# record_15.csv
# record_405.csv
# record_363.csv
# record_377.csv
# record_411.csv
# record_29.csv
# record_388.csv
# record_149.csv
# record_161.csv
# record_607.csv
# record_613.csv
# record_175.csv
# record_1035.csv
# record_820.csv
# record_1021.csv
# record_834.csv
# record_1009.csv
# record_808.csv
# record_997.csv
# record_983.csv
# record_773.csv
# record_767.csv
# record_954.csv
# record_940.csv
# record_798.csv
# record_968.csv
# record_559.csv
# record_571.csv
# record_217.csv
# record_203.csv
# record_565.csv
# record_202.csv
# record_564.csv
# record_570.csv
# record_216.csv
# record_558.csv
# record_969.csv
# record_799.csv
# record_941.csv
# record_955.csv
# record_766.csv
# record_772.csv
# record_982.csv
# record_996.csv
# record_809.csv
# record_1008.csv
# record_835.csv
# record_1020.csv
# record_821.csv
# record_1034.csv
# record_612.csv
# record_174.csv
# record_160.csv
# record_606.csv
# record_148.csv
# record_389.csv
# record_376.csv
# record_28.csv
# record_410.csv
# record_404.csv
# record_362.csv
# record_14.csv
# record_438.csv
# record_16.csv
# record_348.csv
# record_412.csv
# record_374.csv
# record_360.csv
# record_406.csv
# record_638.csv
# record_176.csv
# record_610.csv
# record_604.csv
# record_162.csv
# record_189.csv
# record_1022.csv
# record_837.csv
# record_1036.csv
# record_823.csv
# record_758.csv
# record_980.csv
# record_994.csv
# record_764.csv
# record_770.csv
# record_943.csv
# record_957.csv
# record_228.csv
# record_566.csv
# record_200.csv
# record_214.csv
# record_572.csv
# record_599.csv
# record_598.csv
# record_215.csv
# record_573.csv
# record_567.csv
# record_201.csv
# record_229.csv
# record_956.csv
# record_942.csv
# record_771.csv
# record_765.csv
# record_995.csv
# record_981.csv
# record_759.csv
# record_822.csv
# record_1037.csv
# record_188.csv
# record_836.csv
# record_1023.csv
# record_605.csv
# record_163.csv
# record_177.csv
# record_611.csv
# record_639.csv
# record_361.csv
# record_407.csv
# record_413.csv
# record_375.csv
# record_17.csv
# record_349.csv
# record_371.csv
# record_417.csv
# record_403.csv
# record_365.csv
# record_13.csv
# record_359.csv
# record_615.csv
# record_173.csv
# record_167.csv
# record_601.csv
# record_629.csv
# record_1027.csv
# record_832.csv
# record_198.csv
# record_1033.csv
# record_826.csv
# record_761.csv
# record_775.csv
# record_985.csv
# record_749.csv
# record_991.csv
# record_946.csv
# record_952.csv
# record_205.csv
# record_563.csv
# record_577.csv
# record_211.csv
# record_239.csv
# record_588.csv
# record_589.csv
# record_238.csv
# record_576.csv
# record_210.csv
# record_204.csv
# record_562.csv
# record_953.csv
# record_947.csv
# record_990.csv
# record_748.csv
# record_984.csv
# record_774.csv
# record_760.csv
# record_199.csv
# record_827.csv
# record_1032.csv
# record_833.csv
# record_1026.csv
# record_628.csv
# record_166.csv
# record_600.csv
# record_614.csv
# record_172.csv
# record_358.csv
# record_12.csv
# record_402.csv
# record_364.csv
# record_370.csv
# record_416.csv
# record_366.csv
# record_38.csv
# record_400.csv
# record_414.csv
# record_372.csv
# record_10.csv
# record_428.csv
# record_399.csv
# record_602.csv
# record_164.csv
# record_170.csv
# record_616.csv
# record_158.csv
# record_819.csv
# record_1018.csv
# record_1030.csv
# record_825.csv
# record_1024.csv
# record_831.csv
# record_776.csv
# record_762.csv
# record_992.csv
# record_986.csv
# record_979.csv
# record_951.csv
# record_789.csv
# record_945.csv
# record_212.csv
# record_574.csv
# record_560.csv
# record_206.csv
# record_548.csv
# record_549.csv
# record_561.csv
# record_207.csv
# record_213.csv
# record_575.csv
# record_944.csv
# record_788.csv
# record_950.csv
# record_978.csv
# record_987.csv
# record_993.csv
# record_763.csv
# record_777.csv
# record_830.csv
# record_1025.csv
# record_824.csv
# record_1031.csv
# record_1019.csv
# record_818.csv
# record_159.csv
# record_171.csv
# record_617.csv
# record_603.csv
# record_165.csv
# record_398.csv
# record_429.csv
# record_11.csv
# record_415.csv
# record_373.csv
# record_367.csv
# record_401.csv
# record_39.csv
# record_62.csv
# record_76.csv
# record_328.csv
# record_300.csv
# record_466.csv
# record_472.csv
# record_314.csv
# record_499.csv
# record_7.csv
# record_89.csv
# record_880.csv
# record_658.csv
# record_894.csv
# record_664.csv
# record_102.csv
# record_116.csv
# record_670.csv
# record_1056.csv
# record_843.csv
# record_1042.csv
# record_857.csv
# record_738.csv
# record_710.csv
# record_704.csv
# record_937.csv
# record_923.csv
# record_248.csv
# record_274.csv
# record_512.csv
# record_506.csv
# record_260.csv
# record_507.csv
# record_261.csv
# record_275.csv
# record_513.csv
# record_249.csv
# record_922.csv
# record_936.csv
# record_705.csv
# record_711.csv
# record_739.csv
# record_856.csv
# record_1043.csv
# record_842.csv
# record_1057.csv
# record_117.csv
# record_671.csv
# record_665.csv
# record_103.csv
# record_895.csv
# record_659.csv
# record_881.csv
# record_88.csv
# record_6.csv
# record_498.csv
# record_473.csv
# record_315.csv
# record_301.csv
# record_467.csv
# record_77.csv
# record_329.csv
# record_63.csv
# record_75.csv
# record_61.csv
# record_459.csv
# record_317.csv
# record_49.csv
# record_471.csv
# record_465.csv
# record_303.csv
# record_4.csv
# record_897.csv
# record_129.csv
# record_883.csv
# record_673.csv
# record_115.csv
# record_101.csv
# record_667.csv
# record_1041.csv
# record_854.csv
# record_1055.csv
# record_698.csv
# record_840.csv
# record_868.csv
# record_1069.csv
# record_707.csv
# record_713.csv
# record_920.csv
# record_934.csv
# record_908.csv
# record_539.csv
# record_263.csv
# record_505.csv
# record_511.csv
# record_277.csv
# record_288.csv
# record_289.csv
# record_510.csv
# record_276.csv
# record_262.csv
# record_504.csv
# record_538.csv
# record_909.csv
# record_935.csv
# record_921.csv
# record_712.csv
# record_706.csv
# record_1068.csv
# record_869.csv
# record_841.csv
# record_699.csv
# record_1054.csv
# record_855.csv
# record_1040.csv
# record_100.csv
# record_666.csv
# record_672.csv
# record_114.csv
# record_882.csv
# record_896.csv
# record_128.csv
# record_5.csv
# record_464.csv
# record_302.csv
# record_316.csv
# record_470.csv
# record_48.csv
# record_458.csv
# record_60.csv
# record_74.csv
# record_474.csv
# record_312.csv
# record_306.csv
# record_460.csv
# record_58.csv
# record_448.csv
# record_70.csv
# record_64.csv
# record_1.csv
# record_110.csv
# record_676.csv
# record_662.csv
# record_104.csv
# record_892.csv
# record_886.csv
# record_138.csv
# record_879.csv
# record_1044.csv
# record_689.csv
# record_851.csv
# record_1050.csv
# record_845.csv
# record_702.csv
# record_716.csv
# record_919.csv
# record_925.csv
# record_931.csv
# record_500.csv
# record_266.csv
# record_272.csv
# record_514.csv
# record_528.csv
# record_299.csv
# record_298.csv
# record_529.csv
# record_273.csv
# record_515.csv
# record_501.csv
# record_267.csv
# record_930.csv
# record_924.csv
# record_918.csv
# record_717.csv
# record_703.csv
# record_844.csv
# record_1051.csv
# record_850.csv
# record_688.csv
# record_1045.csv
# record_878.csv
# record_887.csv
# record_139.csv
# record_893.csv
# record_663.csv
# record_105.csv
# record_111.csv
# record_677.csv
# record_65.csv
# record_71.csv
# record_449.csv
# record_307.csv
# record_59.csv
# record_461.csv
# record_475.csv
# record_313.csv
# record_463.csv
# record_305.csv
# record_311.csv
# record_477.csv
# record_67.csv
# record_339.csv
# record_73.csv
# record_98.csv
# record_2.csv
# record_488.csv
# record_107.csv
# record_661.csv
# record_675.csv
# record_113.csv
# record_885.csv
# record_891.csv
# record_649.csv
# record_1053.csv
# record_846.csv
# record_1047.csv
# record_852.csv
# record_715.csv
# record_701.csv
# record_729.csv
# record_932.csv
# record_926.csv
# record_517.csv
# record_271.csv
# record_265.csv
# record_503.csv
# record_259.csv
# record_258.csv
# record_264.csv
# record_502.csv
# record_516.csv
# record_270.csv
# record_927.csv
# record_933.csv
# record_728.csv
# record_700.csv
# record_714.csv
# record_853.csv
# record_1046.csv
# record_847.csv
# record_1052.csv
# record_648.csv
# record_890.csv
# record_884.csv
# record_674.csv
# record_112.csv
# record_106.csv
# record_660.csv
# record_489.csv
# record_3.csv
# record_99.csv
# record_72.csv
# record_66.csv
# record_338.csv
# record_310.csv
# record_476.csv
# record_462.csv
# record_304.csv
#              Action  SCORE  SCORE_ADV  ORDINAL  OUR_TURN  HAS_WON  FINAL_ORD  \
# 0    (5,0) -> (6,0)   1.10        2.2      0.5       1.0      0.0        0.0
# 1    (5,5) -> (6,5)   1.15        2.3      0.5       1.0      0.0        0.0
# 2    (5,0) -> (6,0)   1.10        2.2      0.5       1.0      0.0        0.0
# 3    (5,0) -> (6,0)   1.10        2.1      0.5       1.0      0.0        0.0
# 4    (5,0) -> (6,0)   1.10        2.1      0.5       1.0      0.0        0.0
# ..              ...    ...        ...      ...       ...      ...        ...
# 252  (2,0) -> (3,0)   1.15        2.1      0.5       1.0      0.0        0.0
# 253  (2,0) -> (2,1)   1.15        2.2      0.5       1.0      0.0        0.0
# 254  (3,3) -> (3,4)   1.15        2.2      0.5       1.0      0.0        0.0
# 255  (1,0) -> (1,1)   1.15        2.1      0.5       1.0      0.0        0.0
# 256  (0,2) -> (0,3)   1.20        2.3      0.5       1.0      0.0        0.0
#
#      ROUND  NO_BOXES  ONE_BOXES  TWO_BOXES  THREE_BOXES  \
# 0      0.0       2.0        3.0        7.0          1.0
# 1      0.0       2.0        3.0        7.0          0.0
# 2      0.0       2.0        2.0        6.0          3.0
# 3      0.0       1.0        3.0        6.0          2.0
# 4      0.0       1.0        3.0        7.0          1.0
# ..     ...       ...        ...        ...          ...
# 252    0.0       1.0        3.0        2.0          4.0
# 253    0.0       1.0        1.0        5.0          4.0
# 254    0.0       1.0        2.0        3.0          5.0
# 255    0.0       0.0        3.0        5.0          2.0
# 256    0.0       1.0        2.0        6.0          1.0
#
#      OPPONENTS_FILLED_BOXES  OWNED_FILLED_BOXES
# 0                       0.0                22.0
# 1                       0.0                23.0
# 2                       0.0                22.0
# 3                       1.0                22.0
# 4                       1.0                22.0
# ..                      ...                 ...
# 252                     2.0                23.0
# 253                     1.0                23.0
# 254                     1.0                23.0
# 255                     2.0                23.0
# 256                     1.0                24.0
#
# [88241 rows x 14 columns]

# %%
X = df.drop(columns=['Action'])
y = df['Action']

# Max leaf is the number of action
max_leaf = len(df['Action'].unique())
features = X.columns

# %%
clf = DecisionTreeClassifier(max_leaf_nodes=max_leaf, random_state=42)
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=82, random_state=42)

# %%
text_representation = tree.export_text(clf, feature_names=list(features))
print(text_representation)
# Out:
# |--- SCORE_ADV <= 0.65
# |   |--- NO_BOXES <= 5.50
# |   |   |--- NO_BOXES <= 2.50
# |   |   |   |--- ONE_BOXES <= 17.50
# |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |--- ONE_BOXES >  17.50
# |   |   |   |   |--- class: (0,0) -> (1,0)
# |   |   |--- NO_BOXES >  2.50
# |   |   |   |--- SCORE <= 0.28
# |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |--- SCORE >  0.28
# |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |--- NO_BOXES >  5.50
# |   |   |--- OPPONENTS_FILLED_BOXES <= 0.50
# |   |   |   |--- NO_BOXES <= 33.50
# |   |   |   |   |--- TWO_BOXES <= 9.50
# |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |   |--- TWO_BOXES >  9.50
# |   |   |   |   |   |--- class: (0,1) -> (0,2)
# |   |   |   |--- NO_BOXES >  33.50
# |   |   |   |   |--- class: (0,1) -> (0,2)
# |   |   |--- OPPONENTS_FILLED_BOXES >  0.50
# |   |   |   |--- class: (0,3) -> (0,4)
# |--- SCORE_ADV >  0.65
# |   |--- OWNED_FILLED_BOXES <= 17.50
# |   |   |--- OPPONENTS_FILLED_BOXES <= 0.50
# |   |   |   |--- TWO_BOXES <= 9.50
# |   |   |   |   |--- ONE_BOXES <= 9.50
# |   |   |   |   |   |--- NO_BOXES <= 3.50
# |   |   |   |   |   |   |--- NO_BOXES <= 0.50
# |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |--- NO_BOXES >  0.50
# |   |   |   |   |   |   |   |--- class: (0,4) -> (0,5)
# |   |   |   |   |   |--- NO_BOXES >  3.50
# |   |   |   |   |   |   |--- class: (0,2) -> (0,3)
# |   |   |   |   |--- ONE_BOXES >  9.50
# |   |   |   |   |   |--- NO_BOXES <= 3.50
# |   |   |   |   |   |   |--- NO_BOXES <= 1.50
# |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |--- NO_BOXES >  1.50
# |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |--- NO_BOXES >  3.50
# |   |   |   |   |   |   |--- OWNED_FILLED_BOXES <= 8.50
# |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |--- OWNED_FILLED_BOXES >  8.50
# |   |   |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |--- TWO_BOXES >  9.50
# |   |   |   |   |--- NO_BOXES <= 0.50
# |   |   |   |   |   |--- OWNED_FILLED_BOXES <= 11.50
# |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |--- OWNED_FILLED_BOXES >  11.50
# |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |--- NO_BOXES >  0.50
# |   |   |   |   |   |--- OWNED_FILLED_BOXES <= 11.50
# |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |--- OWNED_FILLED_BOXES >  11.50
# |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |--- OPPONENTS_FILLED_BOXES >  0.50
# |   |   |   |--- OWNED_FILLED_BOXES <= 11.50
# |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |--- OWNED_FILLED_BOXES >  11.50
# |   |   |   |   |--- TWO_BOXES <= 8.50
# |   |   |   |   |   |--- class: (2,2) -> (3,2)
# |   |   |   |   |--- TWO_BOXES >  8.50
# |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |--- OWNED_FILLED_BOXES >  17.50
# |   |   |--- OWNED_FILLED_BOXES <= 25.50
# |   |   |   |--- OPPONENTS_FILLED_BOXES <= 0.50
# |   |   |   |   |--- NO_BOXES <= 0.50
# |   |   |   |   |   |--- SCORE <= 1.12
# |   |   |   |   |   |   |--- ONE_BOXES <= 1.50
# |   |   |   |   |   |   |   |--- OWNED_FILLED_BOXES <= 21.50
# |   |   |   |   |   |   |   |   |--- class: (5,5) -> (6,5)
# |   |   |   |   |   |   |   |--- OWNED_FILLED_BOXES >  21.50
# |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |--- ONE_BOXES >  1.50
# |   |   |   |   |   |   |   |--- SCORE_ADV <= 1.95
# |   |   |   |   |   |   |   |   |--- ONE_BOXES <= 5.50
# |   |   |   |   |   |   |   |   |   |--- class: (5,2) -> (6,2)
# |   |   |   |   |   |   |   |   |--- ONE_BOXES >  5.50
# |   |   |   |   |   |   |   |   |   |--- class: (0,1) -> (1,1)
# |   |   |   |   |   |   |   |--- SCORE_ADV >  1.95
# |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |--- SCORE >  1.12
# |   |   |   |   |   |   |--- THREE_BOXES <= 6.50
# |   |   |   |   |   |   |   |--- ONE_BOXES <= 1.50
# |   |   |   |   |   |   |   |   |--- SCORE <= 1.18
# |   |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |   |   |--- SCORE >  1.18
# |   |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |   |--- ONE_BOXES >  1.50
# |   |   |   |   |   |   |   |   |--- class: (0,5) -> (1,5)
# |   |   |   |   |   |   |--- THREE_BOXES >  6.50
# |   |   |   |   |   |   |   |--- ONE_BOXES <= 0.50
# |   |   |   |   |   |   |   |   |--- class: (5,2) -> (6,2)
# |   |   |   |   |   |   |   |--- ONE_BOXES >  0.50
# |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |--- NO_BOXES >  0.50
# |   |   |   |   |   |--- ONE_BOXES <= 2.50
# |   |   |   |   |   |   |--- OWNED_FILLED_BOXES <= 22.50
# |   |   |   |   |   |   |   |--- NO_BOXES <= 3.50
# |   |   |   |   |   |   |   |   |--- class: (6,2) -> (6,3)
# |   |   |   |   |   |   |   |--- NO_BOXES >  3.50
# |   |   |   |   |   |   |   |   |--- class: (1,3) -> (1,4)
# |   |   |   |   |   |   |--- OWNED_FILLED_BOXES >  22.50
# |   |   |   |   |   |   |   |--- class: (0,2) -> (1,2)
# |   |   |   |   |   |--- ONE_BOXES >  2.50
# |   |   |   |   |   |   |--- ONE_BOXES <= 5.50
# |   |   |   |   |   |   |   |--- SCORE_ADV <= 2.45
# |   |   |   |   |   |   |   |   |--- NO_BOXES <= 2.50
# |   |   |   |   |   |   |   |   |   |--- class: (5,0) -> (6,0)
# |   |   |   |   |   |   |   |   |--- NO_BOXES >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |   |--- SCORE_ADV >  2.45
# |   |   |   |   |   |   |   |   |--- NO_BOXES <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: (3,1) -> (4,1)
# |   |   |   |   |   |   |   |   |--- NO_BOXES >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: (3,1) -> (4,1)
# |   |   |   |   |   |   |--- ONE_BOXES >  5.50
# |   |   |   |   |   |   |   |--- THREE_BOXES <= 2.50
# |   |   |   |   |   |   |   |   |--- class: (0,4) -> (0,5)
# |   |   |   |   |   |   |   |--- THREE_BOXES >  2.50
# |   |   |   |   |   |   |   |   |--- class: (0,5) -> (1,5)
# |   |   |   |--- OPPONENTS_FILLED_BOXES >  0.50
# |   |   |   |   |--- SCORE_ADV <= 2.05
# |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES <= 1.50
# |   |   |   |   |   |   |--- NO_BOXES <= 0.50
# |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |--- NO_BOXES >  0.50
# |   |   |   |   |   |   |   |--- NO_BOXES <= 1.50
# |   |   |   |   |   |   |   |   |--- class: (6,5) -> (7,5)
# |   |   |   |   |   |   |   |--- NO_BOXES >  1.50
# |   |   |   |   |   |   |   |   |--- SCORE <= 0.97
# |   |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |   |   |--- SCORE >  0.97
# |   |   |   |   |   |   |   |   |   |--- class: (5,0) -> (6,0)
# |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES >  1.50
# |   |   |   |   |   |   |--- ONE_BOXES <= 2.50
# |   |   |   |   |   |   |   |--- class: (5,5) -> (6,5)
# |   |   |   |   |   |   |--- ONE_BOXES >  2.50
# |   |   |   |   |   |   |   |--- class: (6,4) -> (6,5)
# |   |   |   |   |--- SCORE_ADV >  2.05
# |   |   |   |   |   |--- SCORE <= 1.18
# |   |   |   |   |   |   |--- NO_BOXES <= 0.50
# |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |--- NO_BOXES >  0.50
# |   |   |   |   |   |   |   |--- class: (1,0) -> (1,1)
# |   |   |   |   |   |--- SCORE >  1.18
# |   |   |   |   |   |   |--- THREE_BOXES <= 4.50
# |   |   |   |   |   |   |   |--- class: (0,1) -> (1,1)
# |   |   |   |   |   |   |--- THREE_BOXES >  4.50
# |   |   |   |   |   |   |   |--- class: (0,1) -> (1,1)
# |   |   |--- OWNED_FILLED_BOXES >  25.50
# |   |   |   |--- SCORE_ADV <= 3.15
# |   |   |   |   |--- OPPONENTS_FILLED_BOXES <= 1.50
# |   |   |   |   |   |--- SCORE <= 1.43
# |   |   |   |   |   |   |--- NO_BOXES <= 0.50
# |   |   |   |   |   |   |   |--- THREE_BOXES <= 4.50
# |   |   |   |   |   |   |   |   |--- OWNED_FILLED_BOXES <= 26.50
# |   |   |   |   |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |   |   |   |   |   |--- OWNED_FILLED_BOXES >  26.50
# |   |   |   |   |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- THREE_BOXES <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |   |   |   |   |   |   |   |--- THREE_BOXES >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: (6,5) -> (7,5)
# |   |   |   |   |   |   |   |--- THREE_BOXES >  4.50
# |   |   |   |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: (5,0) -> (6,0)
# |   |   |   |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: (0,1) -> (1,1)
# |   |   |   |   |   |   |--- NO_BOXES >  0.50
# |   |   |   |   |   |   |   |--- class: (0,2) -> (0,3)
# |   |   |   |   |   |--- SCORE >  1.43
# |   |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES <= 0.50
# |   |   |   |   |   |   |   |--- ONE_BOXES <= 0.50
# |   |   |   |   |   |   |   |   |--- class: (5,0) -> (6,0)
# |   |   |   |   |   |   |   |--- ONE_BOXES >  0.50
# |   |   |   |   |   |   |   |   |--- THREE_BOXES <= 4.50
# |   |   |   |   |   |   |   |   |   |--- class: (0,4) -> (0,5)
# |   |   |   |   |   |   |   |   |--- THREE_BOXES >  4.50
# |   |   |   |   |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES >  0.50
# |   |   |   |   |   |   |   |--- THREE_BOXES <= 1.50
# |   |   |   |   |   |   |   |   |--- class: (4,1) -> (5,1)
# |   |   |   |   |   |   |   |--- THREE_BOXES >  1.50
# |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |--- OPPONENTS_FILLED_BOXES >  1.50
# |   |   |   |   |   |--- SCORE_ADV <= 2.65
# |   |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES <= 3.50
# |   |   |   |   |   |   |   |--- TWO_BOXES <= 1.50
# |   |   |   |   |   |   |   |   |--- TWO_BOXES <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: (0,4) -> (1,4)
# |   |   |   |   |   |   |   |   |--- TWO_BOXES >  0.50
# |   |   |   |   |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- ONE_BOXES <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: (0,0) -> (1,0)
# |   |   |   |   |   |   |   |   |   |   |--- ONE_BOXES >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: (0,4) -> (0,5)
# |   |   |   |   |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: (0,2) -> (1,2)
# |   |   |   |   |   |   |   |--- TWO_BOXES >  1.50
# |   |   |   |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES >  3.50
# |   |   |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES <= 4.50
# |   |   |   |   |   |   |   |   |--- OWNED_FILLED_BOXES <= 29.50
# |   |   |   |   |   |   |   |   |   |--- class: (5,5) -> (6,5)
# |   |   |   |   |   |   |   |   |--- OWNED_FILLED_BOXES >  29.50
# |   |   |   |   |   |   |   |   |   |--- class: (5,5) -> (6,5)
# |   |   |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES >  4.50
# |   |   |   |   |   |   |   |   |--- TWO_BOXES <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |   |   |   |   |   |--- TWO_BOXES >  0.50
# |   |   |   |   |   |   |   |   |   |--- OWNED_FILLED_BOXES <= 28.50
# |   |   |   |   |   |   |   |   |   |   |--- SCORE <= 1.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class: (0,4) -> (0,5)
# |   |   |   |   |   |   |   |   |   |   |--- SCORE >  1.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class: (5,5) -> (6,5)
# |   |   |   |   |   |   |   |   |   |--- OWNED_FILLED_BOXES >  28.50
# |   |   |   |   |   |   |   |   |   |   |--- class: (0,4) -> (0,5)
# |   |   |   |   |   |--- SCORE_ADV >  2.65
# |   |   |   |   |   |   |--- TWO_BOXES <= 1.50
# |   |   |   |   |   |   |   |--- THREE_BOXES <= 0.50
# |   |   |   |   |   |   |   |   |--- FINAL_ORD <= 0.25
# |   |   |   |   |   |   |   |   |   |--- class: (0,0) -> (0,1)
# |   |   |   |   |   |   |   |   |--- FINAL_ORD >  0.25
# |   |   |   |   |   |   |   |   |   |--- class: (2,0) -> (3,0)
# |   |   |   |   |   |   |   |--- THREE_BOXES >  0.50
# |   |   |   |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES <= 2.50
# |   |   |   |   |   |   |   |   |   |--- TWO_BOXES <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: (0,0) -> (1,0)
# |   |   |   |   |   |   |   |   |   |--- TWO_BOXES >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: (0,0) -> (1,0)
# |   |   |   |   |   |   |   |   |--- OPPONENTS_FILLED_BOXES >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: (3,0) -> (4,0)
# |   |   |   |   |   |   |--- TWO_BOXES >  1.50
# |   |   |   |   |   |   |   |--- class: (0,4) -> (1,4)
# |   |   |   |--- SCORE_ADV >  3.15
# |   |   |   |   |--- OPPONENTS_FILLED_BOXES <= 0.50
# |   |   |   |   |   |--- class: (0,3) -> (0,4)
# |   |   |   |   |--- OPPONENTS_FILLED_BOXES >  0.50
# |   |   |   |   |   |--- class: (4,0) -> (5,0)

# %%
action_decisions = []
current_action_set = []

n_nodes = clf.tree_.node_count
children_left = clf.tree_.children_left
children_right = clf.tree_.children_right
feature = clf.tree_.feature
threshold = clf.tree_.threshold

retrieve_tree(clf.tree_, clf.classes_, 0)

# %%
action_feature_dict = defaultdict(list)

for action_decision in action_decisions:
    action_feature_dict[action_decision[-1]].append(action_decision[: -1])
    
for action_name, features in action_feature_dict.items():
    feature_set = set()
    for feature_list in features:
        for feature in feature_list:
            feature_set.add(feature)
        
    print(f"Action Name: {action_name}")
    print(f"Feature List: [{', '.join(list(feature_set))}]")
    print(f"Paths({len(features)}):")
    for idx, feature_list in enumerate(features, 1):
        print(f"\tPath {idx}: {', '.join(feature_list)}")
    print("-" * 115)
    
print("The excluded action list:\n\t", end='')
print('\n\t'.join(set(df['Action'].unique()) ^ set(action_feature_dict.keys())))
# Out:
# Action Name: (0,0) -> (0,1)
# Feature List: [FINAL_ORD, SCORE_ADV, NO_BOXES, TWO_BOXES, SCORE, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, THREE_BOXES, ONE_BOXES]
# Paths(22):
# 	Path 1: SCORE_ADV, NO_BOXES, NO_BOXES, ONE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, ONE_BOXES, NO_BOXES, NO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 3: SCORE_ADV, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, ONE_BOXES, NO_BOXES, NO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 4: SCORE_ADV, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, ONE_BOXES, NO_BOXES, NO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 5: SCORE_ADV, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, ONE_BOXES, NO_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 6: SCORE_ADV, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, NO_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 7: SCORE_ADV, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, NO_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 8: SCORE_ADV, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, NO_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 9: SCORE_ADV, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, NO_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 10: SCORE_ADV, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, TWO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 11: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, SCORE, ONE_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 12: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, SCORE, ONE_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES
# 	Path 13: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, SCORE, THREE_BOXES, ONE_BOXES, SCORE, OPPONENTS_FILLED_BOXES
# 	Path 14: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, SCORE, THREE_BOXES, ONE_BOXES, SCORE, OPPONENTS_FILLED_BOXES
# 	Path 15: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, SCORE, THREE_BOXES, ONE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 16: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, ONE_BOXES, ONE_BOXES, SCORE_ADV, NO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 17: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, NO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 18: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, NO_BOXES, NO_BOXES, SCORE, OPPONENTS_FILLED_BOXES
# 	Path 19: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, SCORE_ADV, SCORE, NO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 20: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE, NO_BOXES, THREE_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 21: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE, OPPONENTS_FILLED_BOXES, THREE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 22: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, TWO_BOXES, THREE_BOXES, FINAL_ORD, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,0) -> (1,0)
# Feature List: [SCORE_ADV, NO_BOXES, TWO_BOXES, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, THREE_BOXES, ONE_BOXES]
# Paths(4):
# 	Path 1: SCORE_ADV, NO_BOXES, NO_BOXES, ONE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, TWO_BOXES, TWO_BOXES, OPPONENTS_FILLED_BOXES, ONE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 3: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, TWO_BOXES, THREE_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 4: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, TWO_BOXES, THREE_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,3) -> (0,4)
# Feature List: [SCORE_ADV, NO_BOXES, SCORE, TWO_BOXES, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, THREE_BOXES, ONE_BOXES]
# Paths(12):
# 	Path 1: SCORE_ADV, NO_BOXES, NO_BOXES, SCORE, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, NO_BOXES, NO_BOXES, SCORE, OPPONENTS_FILLED_BOXES
# 	Path 3: SCORE_ADV, NO_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, TWO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 4: SCORE_ADV, NO_BOXES, OPPONENTS_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 5: SCORE_ADV, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, ONE_BOXES, NO_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 6: SCORE_ADV, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 7: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE, NO_BOXES, THREE_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 8: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE, NO_BOXES, THREE_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, THREE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 9: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE, OPPONENTS_FILLED_BOXES, ONE_BOXES, THREE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 10: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, TWO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 11: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 12: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,1) -> (0,2)
# Feature List: [OPPONENTS_FILLED_BOXES, NO_BOXES, TWO_BOXES, SCORE_ADV]
# Paths(2):
# 	Path 1: SCORE_ADV, NO_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, TWO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, NO_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,4) -> (0,5)
# Feature List: [SCORE_ADV, TWO_BOXES, NO_BOXES, SCORE, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, THREE_BOXES, ONE_BOXES]
# Paths(6):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, ONE_BOXES, NO_BOXES, NO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, ONE_BOXES, ONE_BOXES, THREE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 3: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE, OPPONENTS_FILLED_BOXES, ONE_BOXES, THREE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 4: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, TWO_BOXES, TWO_BOXES, OPPONENTS_FILLED_BOXES, ONE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 5: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, OWNED_FILLED_BOXES, SCORE, OPPONENTS_FILLED_BOXES
# 	Path 6: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,2) -> (0,3)
# Feature List: [SCORE_ADV, TWO_BOXES, NO_BOXES, SCORE, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, ONE_BOXES]
# Paths(2):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, ONE_BOXES, NO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE, NO_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (2,2) -> (3,2)
# Feature List: [OPPONENTS_FILLED_BOXES, TWO_BOXES, OWNED_FILLED_BOXES, SCORE_ADV]
# Paths(1):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, TWO_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (5,5) -> (6,5)
# Feature List: [SCORE_ADV, NO_BOXES, SCORE, TWO_BOXES, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, ONE_BOXES]
# Paths(5):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, SCORE, ONE_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, ONE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 3: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 4: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 5: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, OPPONENTS_FILLED_BOXES, TWO_BOXES, OWNED_FILLED_BOXES, SCORE, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (5,2) -> (6,2)
# Feature List: [SCORE_ADV, NO_BOXES, SCORE, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, THREE_BOXES, ONE_BOXES]
# Paths(2):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, SCORE, ONE_BOXES, SCORE_ADV, ONE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, SCORE, THREE_BOXES, ONE_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,1) -> (1,1)
# Feature List: [SCORE_ADV, NO_BOXES, SCORE, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, THREE_BOXES, ONE_BOXES]
# Paths(4):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, SCORE, ONE_BOXES, SCORE_ADV, ONE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, SCORE_ADV, SCORE, THREE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 3: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, SCORE_ADV, SCORE, THREE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 4: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE, NO_BOXES, THREE_BOXES, OPPONENTS_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,5) -> (1,5)
# Feature List: [SCORE_ADV, NO_BOXES, SCORE, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, THREE_BOXES, ONE_BOXES]
# Paths(2):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, SCORE, THREE_BOXES, ONE_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, ONE_BOXES, ONE_BOXES, THREE_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (6,2) -> (6,3)
# Feature List: [SCORE_ADV, NO_BOXES, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, ONE_BOXES]
# Paths(1):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, ONE_BOXES, OWNED_FILLED_BOXES, NO_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (1,3) -> (1,4)
# Feature List: [SCORE_ADV, NO_BOXES, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, ONE_BOXES]
# Paths(1):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, ONE_BOXES, OWNED_FILLED_BOXES, NO_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,2) -> (1,2)
# Feature List: [SCORE_ADV, NO_BOXES, TWO_BOXES, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, ONE_BOXES]
# Paths(2):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, ONE_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, TWO_BOXES, TWO_BOXES, OPPONENTS_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (5,0) -> (6,0)
# Feature List: [SCORE_ADV, NO_BOXES, SCORE, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, THREE_BOXES, ONE_BOXES]
# Paths(4):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, ONE_BOXES, ONE_BOXES, SCORE_ADV, NO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, NO_BOXES, NO_BOXES, SCORE, OPPONENTS_FILLED_BOXES
# 	Path 3: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE, NO_BOXES, THREE_BOXES, OPPONENTS_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 4: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE, OPPONENTS_FILLED_BOXES, ONE_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (3,1) -> (4,1)
# Feature List: [SCORE_ADV, NO_BOXES, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, ONE_BOXES]
# Paths(2):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, ONE_BOXES, ONE_BOXES, SCORE_ADV, NO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, NO_BOXES, ONE_BOXES, ONE_BOXES, SCORE_ADV, NO_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (6,5) -> (7,5)
# Feature List: [SCORE_ADV, NO_BOXES, SCORE, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, THREE_BOXES]
# Paths(2):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, NO_BOXES, NO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE, NO_BOXES, THREE_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, THREE_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (6,4) -> (6,5)
# Feature List: [OPPONENTS_FILLED_BOXES, ONE_BOXES, OWNED_FILLED_BOXES, SCORE_ADV]
# Paths(1):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, ONE_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (1,0) -> (1,1)
# Feature List: [SCORE_ADV, NO_BOXES, SCORE, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES]
# Paths(1):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, OPPONENTS_FILLED_BOXES, SCORE_ADV, SCORE, NO_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (4,1) -> (5,1)
# Feature List: [SCORE_ADV, SCORE, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, THREE_BOXES]
# Paths(1):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE, OPPONENTS_FILLED_BOXES, THREE_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (0,4) -> (1,4)
# Feature List: [OPPONENTS_FILLED_BOXES, TWO_BOXES, OWNED_FILLED_BOXES, SCORE_ADV]
# Paths(2):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, TWO_BOXES, TWO_BOXES, OPPONENTS_FILLED_BOXES
# 	Path 2: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, TWO_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (2,0) -> (3,0)
# Feature List: [FINAL_ORD, SCORE_ADV, TWO_BOXES, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, THREE_BOXES]
# Paths(1):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, TWO_BOXES, THREE_BOXES, FINAL_ORD, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (3,0) -> (4,0)
# Feature List: [SCORE_ADV, TWO_BOXES, OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, THREE_BOXES]
# Paths(1):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, SCORE_ADV, TWO_BOXES, THREE_BOXES, OPPONENTS_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# Action Name: (4,0) -> (5,0)
# Feature List: [OPPONENTS_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV]
# Paths(1):
# 	Path 1: SCORE_ADV, OWNED_FILLED_BOXES, OWNED_FILLED_BOXES, SCORE_ADV, OPPONENTS_FILLED_BOXES, OPPONENTS_FILLED_BOXES
# -------------------------------------------------------------------------------------------------------------------
# The excluded action list:
# 	(6,1) -> (6,2)
# 	(0,3) -> (1,3)
# 	(1,1) -> (2,1)
# 	(4,4) -> (5,4)
# 	(6,0) -> (7,0)
# 	(6,2) -> (7,2)
# 	(2,1) -> (2,2)
# 	(1,5) -> (2,5)
# 	(2,2) -> (2,3)
# 	(2,3) -> (2,4)
# 	(1,4) -> (1,5)
# 	(4,3) -> (4,4)
# 	(2,3) -> (3,3)
# 	(7,4) -> (7,5)
# 	(4,5) -> (5,5)
# 	(3,4) -> (4,4)
# 	(6,0) -> (6,1)
# 	(4,1) -> (4,2)
# 	(3,2) -> (4,2)
# 	(2,5) -> (3,5)
# 	(3,3) -> (4,3)
# 	(2,1) -> (3,1)
# 	(5,2) -> (5,3)
# 	(2,0) -> (2,1)
# 	(1,2) -> (1,3)
# 	(4,4) -> (4,5)
# 	(1,0) -> (2,0)
# 	(5,4) -> (5,5)
# 	(7,1) -> (7,2)
# 	(4,2) -> (4,3)
# 	(3,3) -> (3,4)
# 	(5,4) -> (6,4)
# 	(6,3) -> (7,3)
# 	(3,5) -> (4,5)
# 	(5,3) -> (6,3)
# 	(5,0) -> (5,1)
# 	(6,4) -> (7,4)
# 	(3,2) -> (3,3)
# 	(7,0) -> (7,1)
# 	(1,2) -> (2,2)
# 	(7,2) -> (7,3)
# 	(7,3) -> (7,4)
# 	(4,3) -> (5,3)
# 	(2,4) -> (2,5)
# 	(6,1) -> (7,1)
# 	(6,3) -> (6,4)
# 	(3,4) -> (3,5)
# 	(4,2) -> (5,2)
# 	(1,3) -> (2,3)
# 	(2,4) -> (3,4)
# 	(5,3) -> (5,4)
# 	(3,0) -> (3,1)
# 	(5,1) -> (6,1)
# 	(5,1) -> (5,2)
# 	(4,0) -> (4,1)
# 	(1,1) -> (1,2)
# 	(3,1) -> (3,2)
# 	(1,4) -> (2,4)

# %%
df.to_csv("db_game_features.csv")

# %% [markdown]
# ## Logistic Regression

# %%
df = pd.read_csv("DB_game_states.csv")

# %%
from sklearn.linear_model import LogisticRegression

# %%
X = df.drop(columns=['Action'])
y = df['Action']

# %%
model = LogisticRegression(random_state=42)
model.fit(X, y)
# Out:
# /Users/yu-jhen/opt/anaconda3/envs/data_analysis/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
model.coef_.shape
# Out:
# (82, 71)

# %%
model.classes_.size
# Out:
# 82

# %%
model.coef_[0]
# Out:
# array([-0.00196071,  0.03009026, -0.00788763, -0.11920204, -0.12894603,
#        -0.0389297 , -0.06865349, -0.03971498, -0.00084274,  0.02981136,
#         0.0758072 , -0.01584995,  0.07871338, -0.00760842,  0.05346856,
#        -0.08070946,  0.02763673,  0.03276572,  0.0237979 ,  0.01488958,
#         0.06330796,  0.04047189,  0.12767439,  0.01577512,  0.00843885,
#         0.11786919,  0.21075607, -0.02733807,  0.0434282 ,  0.0251604 ,
#         0.02693322,  0.02180338,  0.11278346, -0.31929303, -0.49927996,
#         0.10154556,  0.13371899,  0.06397877,  0.05221007, -0.01678322,
#        -0.07507914, -0.09956872, -0.12234095, -0.02486689, -0.03072877,
#         0.07081865,  0.06791905, -0.04568925, -0.02974259, -0.03569506,
#        -0.11246476,  0.05138041, -0.03109896,  0.01341889,  0.04623484,
#        -0.07683708, -0.11409102,  0.05736127, -0.0059896 ,  0.10493996,
#         0.08552512,  0.0151066 ,  0.08611347,  0.05965489,  0.06772668,
#        -0.02283546,  0.06625426,  0.08049473,  0.12359267, -0.0086826 ,
#         0.02100641])

# %%
model.classes_[0]
# Out:
# '(0,0) -> (0,1)'

# %%
model.feature_names_in_
# Out:
# array(['Unnamed: 0', 'Cell_Owner_23', 'Cell_Edge_Count_23',
#        'Cell_Owner_24', 'Cell_Edge_Count_24', 'Cell_Owner_50',
#        'Cell_Edge_Count_50', 'Cell_Owner_51', 'Cell_Edge_Count_51',
#        'Cell_Owner_52', 'Cell_Edge_Count_52', 'Cell_Owner_53',
#        'Cell_Edge_Count_53', 'Cell_Owner_10', 'Cell_Edge_Count_10',
#        'Cell_Owner_54', 'Cell_Edge_Count_54', 'Cell_Owner_11',
#        'Cell_Edge_Count_11', 'Cell_Owner_12', 'Cell_Edge_Count_12',
#        'Cell_Owner_13', 'Cell_Edge_Count_13', 'Cell_Owner_14',
#        'Cell_Edge_Count_14', 'Cell_Owner_40', 'Cell_Edge_Count_40',
#        'Cell_Owner_41', 'Cell_Edge_Count_41', 'Cell_Owner_42',
#        'Cell_Edge_Count_42', 'Cell_Owner_43', 'Cell_Edge_Count_43',
#        'Cell_Owner_00', 'Cell_Edge_Count_00', 'Cell_Owner_44',
#        'Cell_Edge_Count_44', 'Cell_Owner_01', 'Cell_Edge_Count_01',
#        'Cell_Owner_02', 'Cell_Edge_Count_02', 'Cell_Owner_03',
#        'Cell_Edge_Count_03', 'Cell_Owner_04', 'Cell_Edge_Count_04',
#        'Cell_Owner_30', 'Cell_Edge_Count_30', 'Cell_Owner_31',
#        'Cell_Edge_Count_31', 'Cell_Owner_32', 'Cell_Edge_Count_32',
#        'Cell_Owner_33', 'Cell_Edge_Count_33', 'Cell_Owner_34',
#        'Cell_Edge_Count_34', 'Cell_Owner_60', 'Cell_Edge_Count_60',
#        'Cell_Owner_61', 'Cell_Edge_Count_61', 'Cell_Owner_62',
#        'Cell_Edge_Count_62', 'Cell_Owner_63', 'Cell_Edge_Count_63',
#        'Cell_Owner_20', 'Cell_Edge_Count_20', 'Cell_Owner_64',
#        'Cell_Edge_Count_64', 'Cell_Owner_21', 'Cell_Edge_Count_21',
#        'Cell_Owner_22', 'Cell_Edge_Count_22'], dtype=object)

# %%
weights_0 = model.coef_[0]

# %%
weights_0.argsort()
# Out:
# array([34, 33,  4, 42,  3, 56, 50, 41, 15, 55, 40,  6, 47,  7,  5, 49, 52,
#        44, 48, 27, 43, 65, 39, 11, 69,  2, 13, 58,  0,  8, 24, 53, 19, 61,
#        23, 70, 31, 18, 29, 30, 16,  9,  1, 17, 21, 28, 54, 51, 38, 14, 57,
#        63, 20, 37, 66, 64, 46, 45, 10, 12, 67, 60, 62, 35, 59, 32, 25, 68,
#        22, 36, 26])

# %%
model.feature_names_in_[weights_0.argsort()[:5]]
# Out:
# array(['Cell_Edge_Count_00', 'Cell_Owner_00', 'Cell_Edge_Count_24',
#        'Cell_Edge_Count_03', 'Cell_Owner_24'], dtype=object)

# %%
model.feature_names_in_[weights_0.argsort()[-5:]]
# Out:
# array(['Cell_Owner_40', 'Cell_Edge_Count_21', 'Cell_Edge_Count_13',
#        'Cell_Edge_Count_44', 'Cell_Edge_Count_40'], dtype=object)
